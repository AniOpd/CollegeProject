# %%
# !pip install tensorflow opencv-python matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow in c:\users\khair\appdata\roaming\python\python311\site-packages (2.16.1)
# Requirement already satisfied: opencv-python in c:\users\khair\appdata\roaming\python\python311\site-packages (4.9.0.80)
# Requirement already satisfied: matplotlib in c:\users\khair\appdata\roaming\python\python311\site-packages (3.8.3)
# Requirement already satisfied: tensorflow-intel==2.16.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow) (2.16.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (24.3.7)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (24.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in c:\program files\python311\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.62.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.2.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.31.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.26.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\khair\appdata\roaming\python\python311\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from matplotlib) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: pillow>=8 in c:\users\khair\appdata\roaming\python\python311\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\khair\appdata\roaming\python\python311\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.1->tensorflow) (0.43.0)
# Requirement already satisfied: rich in c:\users\khair\appdata\roaming\python\python311\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\khair\appdata\roaming\python\python311\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.0.7)
# Requirement already satisfied: optree in c:\users\khair\appdata\roaming\python\python311\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\khair\appdata\roaming\python\python311\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\khair\appdata\roaming\python\python311\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\khair\appdata\roaming\python\python311\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2024.2.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (3.0.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (2.17.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.1.2)

# %%
# !pip install tensorflow tensorflow-gpu opencv-python matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow in c:\users\khair\appdata\roaming\python\python311\site-packages (2.16.1)
# Collecting tensorflow-gpu
#   Using cached tensorflow-gpu-2.12.0.tar.gz (2.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: opencv-python in c:\users\khair\appdata\roaming\python\python311\site-packages (4.9.0.80)
# Requirement already satisfied: matplotlib in c:\users\khair\appdata\roaming\python\python311\site-packages (3.8.3)
# Requirement already satisfied: tensorflow-intel==2.16.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow) (2.16.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (24.3.7)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (24.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in c:\program files\python311\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.62.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.2.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.31.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.26.4)
# Collecting python_version>"3.7" (from tensorflow-gpu)
#   Using cached python_version-0.0.2-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\khair\appdata\roaming\python\python311\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from matplotlib) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: pillow>=8 in c:\users\khair\appdata\roaming\python\python311\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\khair\appdata\roaming\python\python311\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.1->tensorflow) (0.43.0)
# Requirement already satisfied: rich in c:\users\khair\appdata\roaming\python\python311\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\khair\appdata\roaming\python\python311\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.0.7)
# Requirement already satisfied: optree in c:\users\khair\appdata\roaming\python\python311\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\khair\appdata\roaming\python\python311\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\khair\appdata\roaming\python\python311\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\khair\appdata\roaming\python\python311\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2024.2.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (3.0.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (2.17.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.1.2)
# Using cached python_version-0.0.2-py2.py3-none-any.whl (3.4 kB)
# Building wheels for collected packages: tensorflow-gpu
#   Building wheel for tensorflow-gpu (setup.py): started
#   Building wheel for tensorflow-gpu (setup.py): finished with status 'error'
#   Running setup.py clean for tensorflow-gpu
# Failed to build tensorflow-gpu
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [18 lines of output]
#   Traceback (most recent call last):
#     File "<string>", line 2, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\khair\AppData\Local\Temp\pip-install-7tx0o427\tensorflow-gpu_7d656fdee24c476bae70d728817cfc4f\setup.py", line 37, in <module>
#       raise Exception(TF_REMOVAL_WARNING)
#   Exception:
#
#   =========================================================
#   The "tensorflow-gpu" package has been removed!
#
#   Please install "tensorflow" instead.
#
#   Other than the name, the two packages have been identical
#   since TensorFlow 2.1, or roughly since Sep 2019. For more
#   information, see: pypi.org/project/tensorflow-gpu
#   =========================================================
#
#
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for tensorflow-gpu
# ERROR: Could not build wheels for tensorflow-gpu, which is required to install pyproject.toml-based projects

# %%
pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in c:\users\khair\appdata\roaming\python\python311\site-packages (4.9.0.80)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\khair\appdata\roaming\python\python311\site-packages (from opencv-python) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in c:\users\khair\appdata\roaming\python\python311\site-packages (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\khair\appdata\roaming\python\python311\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from matplotlib) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\khair\appdata\roaming\python\python311\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\khair\appdata\roaming\python\python311\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\khair\appdata\roaming\python\python311\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\khair\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow in c:\users\khair\appdata\roaming\python\python311\site-packages (2.16.1)
# Requirement already satisfied: tensorflow-intel==2.16.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow) (2.16.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (24.3.7)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (24.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in c:\program files\python311\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.62.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.2.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.31.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.1->tensorflow) (0.43.0)
# Requirement already satisfied: rich in c:\users\khair\appdata\roaming\python\python311\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\khair\appdata\roaming\python\python311\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.0.7)
# Requirement already satisfied: optree in c:\users\khair\appdata\roaming\python\python311\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\khair\appdata\roaming\python\python311\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\khair\appdata\roaming\python\python311\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\khair\appdata\roaming\python\python311\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2024.2.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (3.0.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (2.17.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install tensorflow tensorflow-gpu opencv-python matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow in c:\users\khair\appdata\roaming\python\python311\site-packages (2.16.1)
# Collecting tensorflow-gpu
#   Using cached tensorflow-gpu-2.12.0.tar.gz (2.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: opencv-python in c:\users\khair\appdata\roaming\python\python311\site-packages (4.9.0.80)
# Requirement already satisfied: matplotlib in c:\users\khair\appdata\roaming\python\python311\site-packages (3.8.3)
# Requirement already satisfied: tensorflow-intel==2.16.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow) (2.16.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (24.3.7)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (24.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in c:\program files\python311\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.62.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.2.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.31.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.26.4)
# Collecting python_version>"3.7" (from tensorflow-gpu)
#   Using cached python_version-0.0.2-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\khair\appdata\roaming\python\python311\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from matplotlib) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: pillow>=8 in c:\users\khair\appdata\roaming\python\python311\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\khair\appdata\roaming\python\python311\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.1->tensorflow) (0.43.0)
# Requirement already satisfied: rich in c:\users\khair\appdata\roaming\python\python311\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\khair\appdata\roaming\python\python311\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.0.7)
# Requirement already satisfied: optree in c:\users\khair\appdata\roaming\python\python311\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\khair\appdata\roaming\python\python311\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\khair\appdata\roaming\python\python311\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\khair\appdata\roaming\python\python311\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2024.2.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (3.0.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (2.17.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.1.2)
# Using cached python_version-0.0.2-py2.py3-none-any.whl (3.4 kB)
# Building wheels for collected packages: tensorflow-gpu
#   Building wheel for tensorflow-gpu (setup.py): started
#   Building wheel for tensorflow-gpu (setup.py): finished with status 'error'
#   Running setup.py clean for tensorflow-gpu
# Failed to build tensorflow-gpu
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [18 lines of output]
#   Traceback (most recent call last):
#     File "<string>", line 2, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\khair\AppData\Local\Temp\pip-install-it54bb8b\tensorflow-gpu_46e3a9a9534b47b9960e257d83ed5018\setup.py", line 37, in <module>
#       raise Exception(TF_REMOVAL_WARNING)
#   Exception:
#
#   =========================================================
#   The "tensorflow-gpu" package has been removed!
#
#   Please install "tensorflow" instead.
#
#   Other than the name, the two packages have been identical
#   since TensorFlow 2.1, or roughly since Sep 2019. For more
#   information, see: pypi.org/project/tensorflow-gpu
#   =========================================================
#
#
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for tensorflow-gpu
# ERROR: Could not build wheels for tensorflow-gpu, which is required to install pyproject.toml-based projects

# %%
pip install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow in c:\users\khair\appdata\roaming\python\python311\site-packages (2.16.1)
# Requirement already satisfied: tensorflow-intel==2.16.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow) (2.16.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (24.3.7)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (24.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in c:\program files\python311\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.62.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.2.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.31.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.1->tensorflow) (0.43.0)
# Requirement already satisfied: rich in c:\users\khair\appdata\roaming\python\python311\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\khair\appdata\roaming\python\python311\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.0.7)
# Requirement already satisfied: optree in c:\users\khair\appdata\roaming\python\python311\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\khair\appdata\roaming\python\python311\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\khair\appdata\roaming\python\python311\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\khair\appdata\roaming\python\python311\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2024.2.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (3.0.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (2.17.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\khair\appdata\roaming\python\python311\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip update
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: unknown command "update"

# %%
pip install update
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: update in c:\users\khair\appdata\roaming\python\python311\site-packages (0.0.1)
# Requirement already satisfied: style==1.1.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from update) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip list
# Out:
# Package                      VersionNote: you may need to restart the kernel to use updated packages.
#
# ---------------------------- --------------
# absl-py                      2.1.0
# anyio                        4.3.0
# argon2-cffi                  23.1.0
# argon2-cffi-bindings         21.2.0
# arrow                        1.3.0
# asttokens                    2.4.1
# astunparse                   1.6.3
# async-lru                    2.0.4
# attrs                        23.2.0
# Babel                        2.14.0
# beautifulsoup4               4.12.3
# bleach                       6.1.0
# certifi                      2024.2.2
# cffi                         1.16.0
# charset-normalizer           3.3.2
# colorama                     0.4.6
# comm                         0.2.2
# contourpy                    1.2.0
# cycler                       0.12.1
# debugpy                      1.8.1
# decorator                    5.1.1
# defusedxml                   0.7.1
# executing                    2.0.1
# fastjsonschema               2.19.1
# flatbuffers                  24.3.7
# fonttools                    4.50.0
# fqdn                         1.5.1
# gast                         0.5.4
# google-pasta                 0.2.0
# grpcio                       1.62.1
# h11                          0.14.0
# h5py                         3.11.0
# httpcore                     1.0.5
# httpx                        0.27.0
# idna                         3.7
# ipykernel                    6.29.4
# ipython                      8.23.0
# ipywidgets                   8.1.2
# isoduration                  20.11.0
# jax                          0.4.25
# jedi                         0.19.1
# Jinja2                       3.1.3
# json5                        0.9.25
# jsonpointer                  2.4
# jsonschema                   4.21.1
# jsonschema-specifications    2023.12.1
# jupyter                      1.0.0
# jupyter_client               8.6.1
# jupyter-console              6.6.3
# jupyter_core                 5.7.2
# jupyter-events               0.10.0
# jupyter-lsp                  2.2.5
# jupyter_server               2.14.0
# jupyter_server_terminals     0.5.3
# jupyterlab                   4.1.6
# jupyterlab_pygments          0.3.0
# jupyterlab_server            2.26.0
# jupyterlab_widgets           3.0.10
# keras                        3.2.1
# kiwisolver                   1.4.5
# libclang                     18.1.1
# Markdown                     3.6
# markdown-it-py               3.0.0
# MarkupSafe                   2.1.5
# matplotlib                   3.8.3
# matplotlib-inline            0.1.6
# mdurl                        0.1.2
# mediapipe                    0.10.11
# mistune                      3.0.2
# ml-dtypes                    0.3.2
# namex                        0.0.7
# nbclient                     0.10.0
# nbconvert                    7.16.3
# nbformat                     5.10.4
# nest-asyncio                 1.6.0
# notebook                     7.1.2
# notebook_shim                0.2.4
# numpy                        1.26.4
# opencv-contrib-python        4.9.0.80
# opencv-python                4.9.0.80
# opt-einsum                   3.3.0
# optree                       0.11.0
# overrides                    7.7.0
# packaging                    24.0
# pandas                       2.2.2
# pandocfilters                1.5.1
# parso                        0.8.4
# pillow                       10.2.0
# pip                          24.0
# platformdirs                 4.2.0
# prometheus_client            0.20.0
# prompt-toolkit               3.0.43
# protobuf                     3.20.3
# psutil                       5.9.8
# pure-eval                    0.2.2
# pycparser                    2.21
# Pygments                     2.17.2
# pyparsing                    3.1.2
# python-dateutil              2.9.0.post0
# python-json-logger           2.0.7
# pytz                         2024.1
# pywin32                      306
# pywinpty                     2.0.13
# PyYAML                       6.0.1
# pyzmq                        25.1.2
# qtconsole                    5.5.1
# QtPy                         2.4.1
# referencing                  0.34.0
# requests                     2.31.0
# rfc3339-validator            0.1.4
# rfc3986-validator            0.1.1
# rich                         13.7.1
# rpds-py                      0.18.0
# scipy                        1.12.0
# seaborn                      0.13.2
# Send2Trash                   1.8.3
# setuptools                   65.5.0
# six                          1.16.0
# sniffio                      1.3.1
# sounddevice                  0.4.6
# soupsieve                    2.5
# stack-data                   0.6.3
# style                        1.1.0
# tensorboard                  2.16.2
# tensorboard-data-server      0.7.2
# tensorflow                   2.16.1
# tensorflow-intel             2.16.1
# tensorflow-io-gcs-filesystem 0.31.0
# termcolor                    2.4.0
# terminado                    0.18.1
# tinycss2                     1.2.1
# tornado                      6.4
# traitlets                    5.14.2
# types-python-dateutil        2.9.0.20240316
# typing_extensions            4.11.0
# tzdata                       2024.1
# update                       0.0.1
# uri-template                 1.3.0
# urllib3                      2.2.1
# wcwidth                      0.2.13
# webcolors                    1.13
# webencodings                 0.5.1
# websocket-client             1.7.0
# Werkzeug                     3.0.2
# wheel                        0.43.0
# widgetsnbextension           4.0.10
# wrapt                        1.16.0

# %%
pip install tensorflow gpu
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow in c:\users\khair\appdata\roaming\python\python311\site-packages (2.16.1)
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement gpu (from versions: none)
# ERROR: No matching distribution found for gpu

# %%
pip install tensorflow-gpu
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tensorflow-gpu
#   Using cached tensorflow-gpu-2.12.0.tar.gz (2.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting python_version>"3.7" (from tensorflow-gpu)
#   Using cached python_version-0.0.2-py2.py3-none-any.whl.metadata (1.7 kB)
# Using cached python_version-0.0.2-py2.py3-none-any.whl (3.4 kB)
# Building wheels for collected packages: tensorflow-gpu
#   Building wheel for tensorflow-gpu (setup.py): started
#   Building wheel for tensorflow-gpu (setup.py): finished with status 'error'
#   Running setup.py clean for tensorflow-gpu
# Failed to build tensorflow-gpu
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [18 lines of output]
#   Traceback (most recent call last):
#     File "<string>", line 2, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\khair\AppData\Local\Temp\pip-install-p5fwcxsq\tensorflow-gpu_803bedacd9f1493eb1a90f883962bae9\setup.py", line 37, in <module>
#       raise Exception(TF_REMOVAL_WARNING)
#   Exception:
#
#   =========================================================
#   The "tensorflow-gpu" package has been removed!
#
#   Please install "tensorflow" instead.
#
#   Other than the name, the two packages have been identical
#   since TensorFlow 2.1, or roughly since Sep 2019. For more
#   information, see: pypi.org/project/tensorflow-gpu
#   =========================================================
#
#
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for tensorflow-gpu
# ERROR: Could not build wheels for tensorflow-gpu, which is required to install pyproject.toml-based projects

# %%
import tensorflow as tf
import os

# %%
os.path.join('data','happy')
# Out:
# 'data\\happy'

# %%
os.listdir('data')
# Out:
# ['.ipynb_checkpoints', 'happy', 'sad']

# %%
os.listdir('data')
# Out:
# ['.ipynb_checkpoints', 'happy', 'sad']

# %%
gpus=tf.config.experimental.list_physical_devices('GPU')

# %%
gpus=tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu,True)

# %%
pip install numpy scipy scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in c:\users\khair\appdata\roaming\python\python311\site-packages (1.26.4)
# Requirement already satisfied: scipy in c:\users\khair\appdata\roaming\python\python311\site-packages (1.12.0)
# Requirement already satisfied: scikit-learn in c:\users\khair\appdata\roaming\python\python311\site-packages (1.4.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from scikit-learn) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\khair\appdata\roaming\python\python311\site-packages (from scikit-learn) (3.4.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os,glob
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.callbacks import Callback, EarlyStopping
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from sklearn.metrics import classification_report

# %%
file_path = 'dataSet'

# %%
name_class = os.listdir(file_path)
name_class
# Out:
# ['.ipynb_checkpoints', 'acne', 'cellulitis', 'coldSore', 'RingWorm', 'Warts']

# %%
filepaths = list(glob.glob(file_path+'/**/*.*'))

# %%
filepaths
# Out:
# ['dataSet\\acne\\09209-scitech2-acnecxd.jpg',
#  'dataSet\\acne\\1200x799.9999999999999-984814210976.jpg',
#  'dataSet\\acne\\1268-combat-acne-and-scarring-with-red-light-therapy.jpeg',
#  'dataSet\\acne\\1366_2000.jpg',
#  'dataSet\\acne\\16526956228169.jpg',
#  'dataSet\\acne\\1ptl2ymolm911.jpg',
#  'dataSet\\acne\\20125855-how-to-treat-acne-prone-skin-dermatologist-tips_cover_2000x1334.jpg',
#  'dataSet\\acne\\201408-acne-slide4-949x1356.jpg',
#  'dataSet\\acne\\2090499.jpg',
#  'dataSet\\acne\\2185083.jpg',
#  'dataSet\\acne\\2258806.jpeg',
#  'dataSet\\acne\\25015924-147364432583587-5540434140265971712-n.jpg',
#  'dataSet\\acne\\322130_2200-800x1200.jpg',
#  'dataSet\\acne\\3703_Guides_Design_What_Men_Need_To_Know_About_Acne_1.jpg',
#  'dataSet\\acne\\428e20c8-2464-11e9-9177-bd3ae24bba4f_image_hires_123552.JPEG.jpg',
#  'dataSet\\acne\\5318584-6306911-image-a-41_1540294423025.jpg',
#  'dataSet\\acne\\7.jpg',
#  'dataSet\\acne\\719c91fb85a5419aa98e75b6591d3278.jpg',
#  'dataSet\\acne\\78921c62811900fed7ceeebf915a8973.jpg',
#  'dataSet\\acne\\8614.jpg',
#  'dataSet\\acne\\93792.jpg',
#  'dataSet\\acne\\9ea04zta0j451.jpg',
#  'dataSet\\acne\\accc.jpg',
#  'dataSet\\acne\\Acne-1-1068x585.jpg',
#  'dataSet\\acne\\Acne-1-768x432.jpg',
#  'dataSet\\acne\\acne-and-retinol-1.png',
#  'dataSet\\acne\\acne-face-760x428.jpg',
#  'dataSet\\acne\\acne-face.jpeg',
#  'dataSet\\acne\\acne-gel.jpg',
#  'dataSet\\acne\\acne-hormonal.jpg',
#  'dataSet\\acne\\Acne-In-Children.jpg',
#  'dataSet\\acne\\Acne-Light-wave.jpg',
#  'dataSet\\acne\\Acne-Minefield-on-Chest.jpg',
#  'dataSet\\acne\\Acne-Results.jpg',
#  'dataSet\\acne\\acne-rosacea.jpg',
#  'dataSet\\acne\\acne-routine-controversial-social.jpg',
#  'dataSet\\acne\\acne-scarring.jpg',
#  'dataSet\\acne\\Acne-Severity-Grading.jpg',
#  'dataSet\\acne\\acne-severo-cara.jpg',
#  'dataSet\\acne\\acne-treatment-in-Mumbai-acne-scars-treatment-in-Mumbai-before-after.jpg',
#  'dataSet\\acne\\Acne-Vulgaris-treated-in-Delhi-Dr-Sumit-Gupta-SG-Dermatology.jpg',
#  'dataSet\\acne\\Acne-y-cicatrices-4.jpg',
#  'dataSet\\acne\\acne.jpg',
#  'dataSet\\acne\\Acne1-scaled.jpg',
#  'dataSet\\acne\\Acne1.jpg',
#  'dataSet\\acne\\acne10.jpg',
#  'dataSet\\acne\\acne11.jpg',
#  'dataSet\\acne\\acne13.jpg',
#  'dataSet\\acne\\acne14.jpeg',
#  'dataSet\\acne\\acne15.jpg',
#  'dataSet\\acne\\Acne2Bscars2Btreatment.png',
#  'dataSet\\acne\\Acne6.jpg',
#  'dataSet\\acne\\Acne7.jpeg',
#  'dataSet\\acne\\acne7.jpg',
#  'dataSet\\acne\\acne8.jpg',
#  'dataSet\\acne\\acne9.jpg',
#  'dataSet\\acne\\AcneBeforeAndAfter10.jpg',
#  'dataSet\\acne\\acnebeforeshots2.jpg',
#  'dataSet\\acne\\AcneII.jpg',
#  'dataSet\\acne\\acnelesion.jpg',
#  'dataSet\\acne\\acnemakeup.jpg',
#  'dataSet\\acne\\AcneMedica4Samlaska-1024x683.jpg',
#  'dataSet\\acne\\Acnevulgaris.png',
#  'dataSet\\acne\\AcneVulgaris1Samlaska.jpg',
#  'dataSet\\acne\\acnevulgarism-HBC.jpg',
#  'dataSet\\acne\\Acne_CMP-scaled.jpg',
#  'dataSet\\acne\\AdobeStock_61720335.jpeg',
#  'dataSet\\acne\\all2520natural2520acne2520routine2520lede.png',
#  'dataSet\\acne\\aq3djrlxhcvc1.jpeg',
#  'dataSet\\acne\\C.jpg',
#  'dataSet\\acne\\C0384483-Acne_vulgaris.jpg',
#  'dataSet\\acne\\C0384496-Acne_rosacea.jpg',
#  'dataSet\\acne\\C0500875-Acne_rosacea.jpg',
#  'dataSet\\acne\\chico_con_acne.jpg',
#  'dataSet\\acne\\closeup-acne-facial-scars_1140x.jpg',
#  'dataSet\\acne\\Como-eliminar-el-acne-naturalmente-2.jpg',
#  'dataSet\\acne\\copy_1_1000x.png',
#  'dataSet\\acne\\DcBPs6m.png',
#  'dataSet\\acne\\Evidence-Based_2801e9e5-edd5-4d76-b66f-57a55bb780c0_1024x1024.jpg',
#  'dataSet\\acne\\fmkiv72q54c21.jpg',
#  'dataSet\\acne\\fungal-acne.jpg',
#  'dataSet\\acne\\georgia-hitch-skin-cbd.jpg',
#  'dataSet\\acne\\GettyImages-1188910200_header-1024x575.jpg',
#  'dataSet\\acne\\GettyImages-481112395_header-1024x575.jpg',
#  'dataSet\\acne\\hoe-acne-littekens-verminderen-header-1024x551.png',
#  'dataSet\\acne\\hormonal_acne.png',
#  'dataSet\\acne\\How-to-prevent-pimples-or-acne.jpg',
#  'dataSet\\acne\\how2Bto2Bcare2Bacne2Bprone2Bskin.JPG.jpg',
#  'dataSet\\acne\\I6YEH5ODQ6JRINATHEFPPY5XPA.jpg',
#  'dataSet\\acne\\image-asset.png',
#  'dataSet\\acne\\image.jpeg',
#  'dataSet\\acne\\image10.jpg',
#  'dataSet\\acne\\image2.jpeg',
#  'dataSet\\acne\\image3.jpeg',
#  'dataSet\\acne\\image4.jpeg',
#  'dataSet\\acne\\image5.jpeg',
#  'dataSet\\acne\\image8.jpg',
#  'dataSet\\acne\\image9.jpg',
#  'dataSet\\acne\\IMG_0043.JPG.70f9dc7d17dcdf8dbb055d4013e94831.JPG.jpg',
#  'dataSet\\acne\\IMG_3081.JPG.070ca67a37b660c6a022433d8c38e539.JPG.jpg',
#  'dataSet\\acne\\Introducing-Acne-Treatment-Packages-in-Duluth-GA.jpg',
#  'dataSet\\acne\\irevivenashville.com_.png',
#  'dataSet\\acne\\iStock_000022138719Small.jpg',
#  'dataSet\\acne\\j6q86zyclqn21.jpg',
#  'dataSet\\acne\\Jawline-Acne.jpg',
#  'dataSet\\acne\\Kali_Kushner_acne_02.jpg',
#  'dataSet\\acne\\katy-perry-acne.png',
#  'dataSet\\acne\\l8inzi9ta1b21.jpg',
#  'dataSet\\acne\\Laser-Acne-Treatment.jpg',
#  'dataSet\\acne\\LESIONES-ACNE.jpg',
#  'dataSet\\acne\\Maskne-Breakout.jpg',
#  'dataSet\\acne\\maxresdefault15.jpg',
#  'dataSet\\acne\\maxresdefault16.jpg',
#  'dataSet\\acne\\maxresdefault17.jpg',
#  'dataSet\\acne\\maxresdefault3.jpg',
#  'dataSet\\acne\\maxresdefault8.jpg',
#  'dataSet\\acne\\maxresdefault9.jpg',
#  'dataSet\\acne\\MDRUMF_UK_ACNE_NIGHTMARE-2-696x392.jpg',
#  'dataSet\\acne\\MDRUM_Acne_Blindness-3.jpg',
#  'dataSet\\acne\\MENOPAUSAL-ACNE0.jpg',
#  'dataSet\\acne\\nlite-acne-before-after.jpg',
#  'dataSet\\acne\\o-CYSTIC-ACNE-facebook.jpg',
#  'dataSet\\acne\\OIF.010QaTcJC303DN7umLlpjQ.jpg',
#  'dataSet\\acne\\OIF.1a04hGSokjCbd9NnosBQbw.jpg',
#  'dataSet\\acne\\OIF.2jG7Q3LD5TFe7WR5WDO7uw.jpg',
#  'dataSet\\acne\\OIF.2Rc6z8kXeJC0bE0iQeGvQg.jpg',
#  'dataSet\\acne\\OIF.3YbUCDTty3kZ1ilc3JBALQ.jpg',
#  'dataSet\\acne\\OIF.60wLtbIxHIPXjIbCXvmTNA.jpg',
#  'dataSet\\acne\\OIF.7f5nBZNSd3CfqBv7KIoWIQ.jpg',
#  'dataSet\\acne\\OIF.A2PdLnuwCpegrK44h9DAwQ.jpg',
#  'dataSet\\acne\\OIF.a6Xs0HBkL5wGkMnXsfjZZg.jpg',
#  'dataSet\\acne\\OIF.AgLJy13mxDd6VB7jEM3PRg.jpg',
#  'dataSet\\acne\\OIF.Fi5AFmZaO44g6CTiPPQwAQ.jpg',
#  'dataSet\\acne\\OIF.GDptmw9OvjsWLmXgbRK9MQ.jpg',
#  'dataSet\\acne\\OIF.K9jMP6iiYYDZy3WNFbHPsQ.jpg',
#  'dataSet\\acne\\OIF.Ko1NhJkNKIQHzGmsY1njXA.jpg',
#  'dataSet\\acne\\OIF.o8rdNOI5uqH6TJl5cmwbuQ.jpg',
#  'dataSet\\acne\\OIF.QJS4e5SV9NNb4X8up5PZrw.jpg',
#  'dataSet\\acne\\OIF.qtcAqj4khbg5yOss22potg.jpg',
#  'dataSet\\acne\\OIF.S3QOIox3ipx3ryffYRO6zA.jpg',
#  'dataSet\\acne\\OIF.Sz2Ib8JvFNSyMm2chmvAww.jpg',
#  'dataSet\\acne\\OIF.uGOgpFd5Npv8PkAPruSJ0Q.jpg',
#  'dataSet\\acne\\OIF.uy8XjZ3V77FYLU8O4gxuSQ.jpg',
#  'dataSet\\acne\\OIF.vXuWDMeGpMfaEfljTvJMgw.jpg',
#  'dataSet\\acne\\OIF.w0B1kW6UJ3DXSwT7HlM7WQ.jpg',
#  'dataSet\\acne\\phenolsubcisionsculptra1-6.jpg',
#  'dataSet\\acne\\pregnancy-acne-2.png',
#  'dataSet\\acne\\QuitarAcne.jpg',
#  'dataSet\\acne\\rsz_open_grapic.jpg',
#  'dataSet\\acne\\Screenshot-2022-08-29-at-08.26.22-1024x678.png',
#  'dataSet\\acne\\ScreenShot2022-07-09at10.32.33AM.png',
#  'dataSet\\acne\\shoulder-acne.png',
#  'dataSet\\acne\\shutterstock_459808462.jpg',
#  'dataSet\\acne\\skinkissed.co-3.png',
#  'dataSet\\acne\\steroid-acne-2.jpg',
#  'dataSet\\acne\\S_0917_acne_M1080444.width-1019_AVWZW8U.jpg',
#  'dataSet\\acne\\Teenager-with-acne-e1550065116459.jpg',
#  'dataSet\\acne\\tipo-acne-no-debes-reventar-quistico.jpg',
#  'dataSet\\acne\\tmp_jwz13U_d5f141e814b8a8a2_GettyImages-1053179478.jpg',
#  'dataSet\\acne\\tratamiento-acne2-1024x1024.jpg',
#  'dataSet\\acne\\Types-of-acne-1.jpg',
#  'dataSet\\acne\\types-of-acne-scars.png',
#  'dataSet\\acne\\velvetmedspa.com_.png',
#  'dataSet\\acne\\What-Are-The-Causes-Of-Acne.jpg',
#  'dataSet\\acne\\Woman-With-Acne.jpg',
#  'dataSet\\acne\\young-teenage-boy-looking-serious-with-acne-on-his-face-16x9.jpg',
#  'dataSet\\acne\\zveqmplnmcvbcz2qhrob.jpg',
#  'dataSet\\acne\\_42103166_acne203.jpg',
#  'dataSet\\acne\\_55081113_acne-spl-1.jpg',
#  'dataSet\\cellulitis\\06_cellulitis_s-aureus_dia-jan.jpg',
#  'dataSet\\cellulitis\\1200x628_condition_0010_cellulitis-735x0.jpg',
#  'dataSet\\cellulitis\\152663_2200-1200x628.jpg',
#  'dataSet\\cellulitis\\17.jpg',
#  'dataSet\\cellulitis\\20161026_062441.jpg',
#  'dataSet\\cellulitis\\324460_1100-1100x628.jpg',
#  'dataSet\\cellulitis\\324460_1100.jpg',
#  'dataSet\\cellulitis\\3c1a0e.jpg',
#  'dataSet\\cellulitis\\5-cellulitis-dr-p-marazziscience-photo-library.jpg',
#  'dataSet\\cellulitis\\546236429bc85539a52d0561402b407f.jpg',
#  'dataSet\\cellulitis\\a-simple-cellulitis-of-the-foot.png',
#  'dataSet\\cellulitis\\a5ebeb406c4a703d046c7fd901bcaa82.jpg',
#  'dataSet\\cellulitis\\a79555.jpg',
#  'dataSet\\cellulitis\\Blog-Image_Cellulitis_SS_v01.jpg',
#  'dataSet\\cellulitis\\C0215596-Cellulitis_of_the_foot-SPL.width-1534.jpg',
#  'dataSet\\cellulitis\\C0215596-Cellulitis_of_the_foot-SPL.width-610.jpg',
#  'dataSet\\cellulitis\\C0284381-Cellulitis_following_toe_.2e16d0ba.fill-640x427.jpg',
#  'dataSet\\cellulitis\\C0426406-Cellulitis_of_the_leg.jpg',
#  'dataSet\\cellulitis\\cell-3-768x510.jpg',
#  'dataSet\\cellulitis\\Cellulitis-1.jpg',
#  'dataSet\\cellulitis\\Cellulitis-1024x1024.jpg',
#  'dataSet\\cellulitis\\Cellulitis-20160119110757593.jpg',
#  'dataSet\\cellulitis\\Cellulitis-ArticleMeme-716x716.jpg',
#  'dataSet\\cellulitis\\cellulitis-everything-you-need-to-know-fb.jpg',
#  'dataSet\\cellulitis\\cellulitis-feat-1.jpg',
#  'dataSet\\cellulitis\\cellulitis-from-a-bug-bite-on-the-leg.jpg',
#  'dataSet\\cellulitis\\Cellulitis-leg-1024x768.jpg',
#  'dataSet\\cellulitis\\Cellulitis-leg.jpg',
#  'dataSet\\cellulitis\\cellulitis-of-the-ear-and-neck-dr-p-marazziscience-photo-library.jpg',
#  'dataSet\\cellulitis\\cellulitis-on-the-leg-image-credit-john-campbell-2018.jpg',
#  'dataSet\\cellulitis\\cellulitis-pictures-symptoms-treatment-contagious-causes-types.jpg',
#  'dataSet\\cellulitis\\cellulitis-pictures-symptoms-treatment-contagious-causes-types2.jpg',
#  'dataSet\\cellulitis\\cellulitis-skin-rash.png',
#  'dataSet\\cellulitis\\Cellulitis-symptoms.jpg',
#  'dataSet\\cellulitis\\Cellulitis-treating.jpg',
#  'dataSet\\cellulitis\\Cellulitis.jpg',
#  'dataSet\\cellulitis\\cellulitis2-1920x1451.jpg',
#  'dataSet\\cellulitis\\cellulitis3-1536x1152.jpg',
#  'dataSet\\cellulitis\\cellulitis3.jpg',
#  'dataSet\\cellulitis\\cellulitis_03_.jpg',
#  'dataSet\\cellulitis\\chamberlain_cellulitis_001.jpg',
#  'dataSet\\cellulitis\\chamberlain_cellulitis_004.jpg',
#  'dataSet\\cellulitis\\d04179.jpg',
#  'dataSet\\cellulitis\\D4XfDOrX4AgjKQ5.png',
#  'dataSet\\cellulitis\\d6d4d832828c72d27d922fe5562af87b--cellulitis-infection-cellulitis-remedies.jpg',
#  'dataSet\\cellulitis\\d9514f4dab7d543f149985935c88e13e.jpg',
#  'dataSet\\cellulitis\\DSC_6454.JPG.jpg',
#  'dataSet\\cellulitis\\eci5.png',
#  'dataSet\\cellulitis\\f8143413892dbafa07e615d99a62efa2.jpg',
#  'dataSet\\cellulitis\\facial-cellulitis.jpg',
#  'dataSet\\cellulitis\\id005_cellulitis_img1_au.large.jpg',
#  'dataSet\\cellulitis\\image-asset.jpeg',
#  'dataSet\\cellulitis\\image.jpeg',
#  'dataSet\\cellulitis\\image10.jpeg',
#  'dataSet\\cellulitis\\image11.jpg',
#  'dataSet\\cellulitis\\image12.jpg',
#  'dataSet\\cellulitis\\image13.jpg',
#  'dataSet\\cellulitis\\image14.jpg',
#  'dataSet\\cellulitis\\image2.jpeg',
#  'dataSet\\cellulitis\\image3.jpeg',
#  'dataSet\\cellulitis\\image4.jpeg',
#  'dataSet\\cellulitis\\image5.jpeg',
#  'dataSet\\cellulitis\\image6.jpeg',
#  'dataSet\\cellulitis\\image7.jpeg',
#  'dataSet\\cellulitis\\image8.jpeg',
#  'dataSet\\cellulitis\\image9.jpeg',
#  'dataSet\\cellulitis\\img_0857-1.jpg',
#  'dataSet\\cellulitis\\IMG_8779-1.jpg',
#  'dataSet\\cellulitis\\Left_cellulitis_of_leg.jpg',
#  'dataSet\\cellulitis\\M1300322-Cellulitis_on_the_leg.jpg',
#  'dataSet\\cellulitis\\maxresdefault2.jpg',
#  'dataSet\\cellulitis\\maxresdefault3.jpg',
#  'dataSet\\cellulitis\\OIP.01d_52AmflYrXC2RmsFPyQHaE8.jpg',
#  'dataSet\\cellulitis\\OIP.0jgk2XWpIcs_-omKObisHAHaDt.jpg',
#  'dataSet\\cellulitis\\OIP.17BkH9PG91DoeZl5n6UNygHaE6.jpg',
#  'dataSet\\cellulitis\\OIP.1itwT7PC1BTveQfSB8omwQHaE7.jpg',
#  'dataSet\\cellulitis\\OIP.1WO5V_2QhG1E_fdoai82mgHaFU.jpg',
#  'dataSet\\cellulitis\\OIP.1Y0I_zdPs8kgCrpHyuhIYAHaGV.jpg',
#  'dataSet\\cellulitis\\OIP.37pveSgHvjycqewGrMzdJwHaLH.jpg',
#  'dataSet\\cellulitis\\OIP.3eaORQTC46Wcb2X7WXRQpgHaEK.jpg',
#  'dataSet\\cellulitis\\OIP.3jSH9JK7dyvENcv2Naq5jgHaDi.jpg',
#  'dataSet\\cellulitis\\OIP.42E0d3OQ0bHONJHozJUQkAHaEK.jpg',
#  'dataSet\\cellulitis\\OIP.4E3JWOKTOoUDHKpuxpHOVQHaEz.jpg',
#  'dataSet\\cellulitis\\OIP.4n6RGZbpTl-XrQUIlcMXRgHaE8.jpg',
#  'dataSet\\cellulitis\\OIP.5nys1laxqB92HBWlu2i1mwHaHa.jpg',
#  'dataSet\\cellulitis\\OIP.6TH49n4G6LJ_kXFcNkrFQAHaFH.jpg',
#  'dataSet\\cellulitis\\OIP.77B3DqfmB7E31gSOiGH8jQHaE9.jpg',
#  'dataSet\\cellulitis\\OIP.8YrEdTwjzPCSQeCHSKaEeQHaE0.jpg',
#  'dataSet\\cellulitis\\OIP.9blzfdI06KaNxJVARbmi1QHaEJ.jpg',
#  'dataSet\\cellulitis\\OIP.A0HQfLBEA4YFbZkbDbsVKwHaEL.jpg',
#  'dataSet\\cellulitis\\OIP.AiDzpcMmQ4gl1ulP7q6XsAHaFj.jpg',
#  'dataSet\\cellulitis\\OIP.bg9P61z2wAndy9max89-CwHaE0.jpg',
#  'dataSet\\cellulitis\\OIP.BgRAQq1JXr-iw7-xASwy9QHaEK.jpg',
#  'dataSet\\cellulitis\\OIP.CKIioxNkLwycXpEBLCIMzQHaFi.jpg',
#  'dataSet\\cellulitis\\OIP.CQ1P1Nmu3PxWQcoQ8pdvaAHaE7.jpg',
#  'dataSet\\cellulitis\\OIP.d7N_-nuuaXIi5E_GnFMWKgHaEK.jpg',
#  'dataSet\\cellulitis\\OIP.D8ya79XrU4VgC8zcDKuSvwHaIt.jpg',
#  'dataSet\\cellulitis\\OIP.DolXRP4CTIKN3fl00gfhwAHaFj.jpg',
#  'dataSet\\cellulitis\\OIP.dqLrEq1NIuiswlX8cZTTnAHaEO.jpg',
#  'dataSet\\cellulitis\\OIP.ebB7iHCmrFbFbYkze7qJvgHaLH.jpg',
#  'dataSet\\cellulitis\\OIP.eMxdlG9G9QA6zCM0oZEG-AHaEL.jpg',
#  'dataSet\\cellulitis\\OIP.En1bTNs87ZN9pjBbUNqWugHaE6.jpg',
#  'dataSet\\cellulitis\\OIP.EQPlOqKKP1SxeLAZrQ9ICAHaFX.jpg',
#  'dataSet\\cellulitis\\OIP.f-0EY8UnQ0pToLCOdIKz5wHaLH.jpg',
#  'dataSet\\cellulitis\\OIP.F5HWklCfzg_QFzF0WMHOnwHaFm.jpg',
#  'dataSet\\cellulitis\\OIP.FlIoLeng2rTgssWIxPBaYwHaFj.jpg',
#  'dataSet\\cellulitis\\OIP.fXajXPf9-7x7coFXTYRtMwHaE5.jpg',
#  'dataSet\\cellulitis\\OIP.gCyJvJxF6H9KuyTZ8AW6WgHaFj.jpg',
#  'dataSet\\cellulitis\\OIP.GOoyoDg1IyCdg9Qag_1TxAHaNj.jpg',
#  'dataSet\\cellulitis\\OIP.GvZvs9Vjv6gGt6RktLRCzwHaE7.jpg',
#  'dataSet\\cellulitis\\OIP.hIAcrQ-r1h9BtcjTq8kwogHaE8.jpg',
#  'dataSet\\cellulitis\\OIP.hmb01WxZTnntfqOJsNe9lwHaFj.jpg',
#  'dataSet\\cellulitis\\OIP.hsAyN6Oi_AlO2FTQPdbilwHaFj.jpg',
#  'dataSet\\cellulitis\\OIP.IC1OIAEvTArhLpcqO_NuoQHaFj.jpg',
#  'dataSet\\cellulitis\\OIP.iFP-xEy9nsNJvcUO9HxGCgHaFj.jpg',
#  'dataSet\\cellulitis\\OIP.IOLKAgk3uQDZFghDKxP7PgHaFh.jpg',
#  'dataSet\\cellulitis\\OIP.jIujTBJTEutzsJly4gacugHaD5.jpg',
#  'dataSet\\cellulitis\\OIP.jOVOdBgycJ-hcxO1S2Ef9wHaFj.jpg',
#  'dataSet\\cellulitis\\OIP.kSCyaxRZatfAwFNuvmyUCgHaFj.jpg',
#  'dataSet\\cellulitis\\OIP.K_TiSqkpIeWg6uSV0wGIfAAAAA.jpg',
#  'dataSet\\cellulitis\\OIP.L9C7Z0omIMR9QMRHAtCatwHaE6.jpg',
#  'dataSet\\cellulitis\\OIP.LA-Kc0EjsHYspMmZuVH-qAHaFj.jpg',
#  'dataSet\\cellulitis\\OIP.lOHkd6iiCw3FdvYGmQZcJwHaDx.jpg',
#  'dataSet\\cellulitis\\OIP.LwmF0lDNOEobW8G6rOxdwgHaFk.jpg',
#  'dataSet\\cellulitis\\OIP.mDODxqEastekbQpqmLE2_gHaEE.jpg',
#  'dataSet\\cellulitis\\OIP.NajWSad04sut2PmbKXO08QHaE5.jpg',
#  'dataSet\\cellulitis\\OIP.ne7bz7_FzTebkQBr7x3HHQHaHa.jpg',
#  'dataSet\\cellulitis\\OIP.nSQZj4tkocZuPuUqhA5-OAHaEK.jpg',
#  'dataSet\\cellulitis\\OIP.OIzTfna2dKNSQ2sHZ9V-6AHaLH.jpg',
#  'dataSet\\cellulitis\\OIP.oPfn1HUjFO74t5v6HMKO6AHaE1.jpg',
#  'dataSet\\cellulitis\\OIP.OPOjCRZMQlOZSLrUye-ttgHaD3.jpg',
#  'dataSet\\cellulitis\\OIP.orqbg5COccBlYB0m1f9LOgHaDm.jpg',
#  'dataSet\\cellulitis\\OIP.P57wBLqUfFPkfRRgr0a4YgHaFi.jpg',
#  'dataSet\\cellulitis\\OIP.po2P8olUncAT7KUzExz-FAHaHd.jpg',
#  'dataSet\\cellulitis\\OIP.QAETMcqxchPbRjABiX-wtgHaFl.jpg',
#  'dataSet\\cellulitis\\OIP.QaIY3ykVEoMddWF2Dbm9wAHaFj.jpg',
#  'dataSet\\cellulitis\\OIP.qU60AKUMmkcqcXhQ-7XuXgAAAA.jpg',
#  'dataSet\\cellulitis\\OIP.RaXI4rab9UGMucPBWWMDPQHaDt.jpg',
#  'dataSet\\cellulitis\\OIP.rsWUFelsiOxRSF-Lbrs2SQHaHa.jpg',
#  'dataSet\\cellulitis\\OIP.s4AjSeR4VLZSndU_QZnEBgHaEy.jpg',
#  'dataSet\\cellulitis\\OIP.Tjs6BB80j0yPvCwFRyDfagHaE9.jpg',
#  'dataSet\\cellulitis\\OIP.uOmBmra_ga4mBUdHPvcV0QHaHa.jpg',
#  'dataSet\\cellulitis\\OIP.UslPWTjA09JesHHsknZ0lAHaE9.jpg',
#  'dataSet\\cellulitis\\OIP.UUVMHVzlUWexf1kE-bJy-QHaE5.jpg',
#  'dataSet\\cellulitis\\OIP.V7vGjX6uONsIOQzr06Gm0gAAAA.jpg',
#  'dataSet\\cellulitis\\OIP.VhPcEGZ9AIvqQp-0pmJwSAHaFA.jpg',
#  'dataSet\\cellulitis\\OIP.W-seFZSYQhyxi-BKy9e1vwHaJ4.jpg',
#  'dataSet\\cellulitis\\OIP.Wem5S6CaBX3ef2rTnYge3wHaD4.jpg',
#  'dataSet\\cellulitis\\OIP.WpSfKcYT_FUL7OrWfbLTkAHaNA.jpg',
#  'dataSet\\cellulitis\\OIP.wUq3kAH2bJyiq40ry5QGqgHaHa.jpg',
#  'dataSet\\cellulitis\\OIP.Xpaeh84DZj60EaTEbJiHKwHaEK.jpg',
#  'dataSet\\cellulitis\\OIP.XpGsYsXLQWIfxEC4cocZyQHaEl.jpg',
#  'dataSet\\cellulitis\\OIP.xSJkgRe4ubaz1cPcUEaDRQHaE8.jpg',
#  'dataSet\\cellulitis\\OIP.yBLllaaCi7m-uqWY3VFyrQHaH5.jpg',
#  'dataSet\\cellulitis\\OIP.YM0XFszgN2vBSTzse8fNPQAAAA.jpg',
#  'dataSet\\cellulitis\\OIP.YumvMc497dvvdaWmyK6LfQHaEK.jpg',
#  'dataSet\\cellulitis\\OIP.zeDzZy23zongfb94eW4zCAHaHa.jpg',
#  'dataSet\\cellulitis\\OIP.ZhrmBii-s0aLUbWwuWCf9gHaE9.jpg',
#  'dataSet\\cellulitis\\OIP.ZQeTs5cxi4T0JGDxl-47ugHaFj.jpg',
#  'dataSet\\cellulitis\\OIP.zqNzEg0DTkVU509n2OOxeQHaPN.jpg',
#  'dataSet\\cellulitis\\OIP.zXWRWHrrh8YCS4pUAtcLrAHaEK.jpg',
#  'dataSet\\cellulitis\\OIP._5eSdry1MnJNQBP5AjkT3gHaHa.jpg',
#  'dataSet\\cellulitis\\ophthalmology-periorbital-cellulits-clinical-photo-original.jpeg',
#  'dataSet\\cellulitis\\orbital-cellulitis-pic.jpg',
#  'dataSet\\cellulitis\\periorbital-cellulitis_4x3.jpg',
#  'dataSet\\cellulitis\\Periorbital_cellulitis.jpg',
#  'dataSet\\cellulitis\\shutterstock-1694453083-663731.jpg',
#  'dataSet\\cellulitis\\th.jpg',
#  'dataSet\\cellulitis\\th3.jpg',
#  'dataSet\\cellulitis\\th5.jpg',
#  'dataSet\\cellulitis\\th6.jpg',
#  'dataSet\\cellulitis\\th7.jpg',
#  'dataSet\\coldSore\\1-copy-3.png',
#  'dataSet\\coldSore\\112a25035afc020ec2987a89312ab5bb.jpg',
#  'dataSet\\coldSore\\11977-featured_image-how-to-tell-if-its-a-canker-sore-cold-sore-or-more-serious.jpg',
#  'dataSet\\coldSore\\1200px-Aphthe_Unterlippe.jpg',
#  'dataSet\\coldSore\\1296x660_Cold_Sore_STAGE_4-5.jpg',
#  'dataSet\\coldSore\\13-tips-on-how-to-get-rid-of-cold-sores-naturally.jpg',
#  'dataSet\\coldSore\\13011045_f120.jpg',
#  'dataSet\\coldSore\\13881-fb_image-cold-sore-treatment.jpg',
#  'dataSet\\coldSore\\15.jpg',
#  'dataSet\\coldSore\\174eed78dd4b53468884ed8f584c4e0e.jpg',
#  'dataSet\\coldSore\\1_7.jpg',
#  'dataSet\\coldSore\\2-oral-cavity-diseases-cold-sores-thumb.jpg',
#  'dataSet\\coldSore\\20-coldSore-3.jpg',
#  'dataSet\\coldSore\\25E4C01F-64E4-44CC-A8CF-82992E68D599.jpg',
#  'dataSet\\coldSore\\2ade3052d33dd41679fb46b4e6c60bcc.jpg',
#  'dataSet\\coldSore\\311864_2200-800x1200.jpg',
#  'dataSet\\coldSore\\324707_1100.jpg',
#  'dataSet\\coldSore\\41KEUzEGLhL.jpg',
#  'dataSet\\coldSore\\41rqE7hAWTL._SL500_.jpg',
#  'dataSet\\coldSore\\491540236.jpg',
#  'dataSet\\coldSore\\51ko66qeXJL.jpg',
#  'dataSet\\coldSore\\51NSultFHJL._SL500_.jpg',
#  'dataSet\\coldSore\\51uOgfov28L._SL500_.jpg',
#  'dataSet\\coldSore\\51vtukMvNCL._SL500_.jpg',
#  'dataSet\\coldSore\\576600124.jpg',
#  'dataSet\\coldSore\\61F9S264qZL._AC_SL1500_.jpg',
#  'dataSet\\coldSore\\636212334386855192-LIFE-HEALTH-COLDSORES-MYO.jpg',
#  'dataSet\\coldSore\\642x361_Cold_Sores.jpg',
#  'dataSet\\coldSore\\642x361_Cold_Sores2.jpg',
#  'dataSet\\coldSore\\775b48b0fb.jpg',
#  'dataSet\\coldSore\\7965641_f120.jpg',
#  'dataSet\\coldSore\\8229999_f248.jpg',
#  'dataSet\\coldSore\\8230049_f260.jpg',
#  'dataSet\\coldSore\\8402707_f520.jpg',
#  'dataSet\\coldSore\\8402711_f520.jpg',
#  'dataSet\\coldSore\\8637535_f120.jpg',
#  'dataSet\\coldSore\\A-Z_cold-sore_22012020.jpg',
#  'dataSet\\coldSore\\AdobeStock_82169454__1615401841_79513.jpg',
#  'dataSet\\coldSore\\b5322167f023aca9ac657b9c16077d2f.jpg',
#  'dataSet\\coldSore\\bigstock-Cold-Sores-Vector-Illustration-298613602_1200x.jpg',
#  'dataSet\\coldSore\\C0033053-Cold_sore_on_the_face.jpg',
#  'dataSet\\coldSore\\C0051937-Cold_sores_on_the_upper_lip.jpg',
#  'dataSet\\coldSore\\C0117499-Cold_sore_on_the_lower_lip.jpg',
#  'dataSet\\coldSore\\C0167375-Cold_sores_around_the_mouth.jpg',
#  'dataSet\\coldSore\\C0382080-Cold_sores_on_lips.jpg',
#  'dataSet\\coldSore\\c651f910b967e1a2adff3e9a7cfa4e98.jpg',
#  'dataSet\\coldSore\\canker-sore-body1.jpg',
#  'dataSet\\coldSore\\canker-sore.jpg',
#  'dataSet\\coldSore\\ch-coldsorescauses-1490x600.jpeg',
#  'dataSet\\coldSore\\cold-sore-1.jpg',
#  'dataSet\\coldSore\\cold-sore-1024x640.jpeg',
#  'dataSet\\coldSore\\cold-sore-1200x750.jpeg',
#  'dataSet\\coldSore\\cold-sore-blister-1-May-2013.jpg',
#  'dataSet\\coldSore\\cold-sore-lesion-on-upper-lip-dr-p-marazziscience-photo-library.jpg',
#  'dataSet\\coldSore\\cold-sore-lip.jpg',
#  'dataSet\\coldSore\\cold-sore-near-lip.jpg',
#  'dataSet\\coldSore\\Cold-sore-on-lip.jpg',
#  'dataSet\\coldSore\\cold-sore-on-lip2.jpg',
#  'dataSet\\coldSore\\cold-sore-on-lip3.jpg',
#  'dataSet\\coldSore\\cold-sore-on-woman-lip-stage-2.jpg',
#  'dataSet\\coldSore\\cold-sore-on-woman-lip-stage-3.jpg',
#  'dataSet\\coldSore\\cold-sore-outbreaks.jpg',
#  'dataSet\\coldSore\\cold-sore-stages-natural-remedies_orig.png',
#  'dataSet\\coldSore\\Cold-Sore-Symptoms.jpeg',
#  'dataSet\\coldSore\\Cold-Sore-Treatment-Coral-Springs-Florida-1024x371.jpg',
#  'dataSet\\coldSore\\Cold-Sore-Treatment-Coral-Springs-Florida.jpg',
#  'dataSet\\coldSore\\Cold-Sore-vs-Canker-Sore-1.jpg',
#  'dataSet\\coldSore\\cold-sore-vs-canker-sore-722x406.jpg',
#  'dataSet\\coldSore\\cold-sore-vs-canker-sore.jpg',
#  'dataSet\\coldSore\\Cold-sore.jpg',
#  'dataSet\\coldSore\\cold-sore2.jpg',
#  'dataSet\\coldSore\\cold-sore5(1).jpg',
#  'dataSet\\coldSore\\cold-sore5.jpg',
#  'dataSet\\coldSore\\Cold-Sores-1.jpg',
#  'dataSet\\coldSore\\Cold-Sores-Introduction-Entry-Symptoms-Diagnosis-and-Cure-1024x576.jpg',
#  'dataSet\\coldSore\\cold-sores-l.jpg',
#  'dataSet\\coldSore\\Cold-Sores-Naturally.jpg',
#  'dataSet\\coldSore\\Cold-Sores-Perri-03162023-1-1.png',
#  'dataSet\\coldSore\\cold-sores-symptoms-diagnosis-722x406.jpg',
#  'dataSet\\coldSore\\cold-sores-treatment.jpg',
#  'dataSet\\coldSore\\Cold-Sores.jpg',
#  'dataSet\\coldSore\\Cold-Sores2.jpg',
#  'dataSet\\coldSore\\cold-sores3.jpg',
#  'dataSet\\coldSore\\cold-sores4.jpeg',
#  'dataSet\\coldSore\\cold-sores5.jpg',
#  'dataSet\\coldSore\\cold-sores6.jpg',
#  'dataSet\\coldSore\\cold.jpg',
#  'dataSet\\coldSore\\cold2Bsores.jpg',
#  'dataSet\\coldSore\\ColdSoresArticleMemev2.jpg',
#  'dataSet\\coldSore\\Cold_sore.jpg',
#  'dataSet\\coldSore\\cold_sores.jpg',
#  'dataSet\\coldSore\\coping-with-cold-sores-s12-herpes-sore-under-nose.jpg',
#  'dataSet\\coldSore\\Cure-Cold-Sores.jpg',
#  'dataSet\\coldSore\\d4caa159277e53cf0de5a99539db7ebd.jpg',
#  'dataSet\\coldSore\\Dollarphotoclub_73853058.jpg',
#  'dataSet\\coldSore\\fa1c44bdbcd6b7f877e1f3577aeaf957.jpg',
#  'dataSet\\coldSore\\face-stg3-zoom.jpg',
#  'dataSet\\coldSore\\featured-cold-sore-causes-remedies.jpg',
#  'dataSet\\coldSore\\fotolia_12721742_XS.jpg',
#  'dataSet\\coldSore\\frequently-asked-questions-about-canker-sores-722x406.jpg',
#  'dataSet\\coldSore\\get-rid-of-cold-sore-fast-1024x682.jpg',
#  'dataSet\\coldSore\\Get-Rid-Of-Cold-Sores2-400x312.jpg',
#  'dataSet\\coldSore\\Grey-Minimalist-Difference-And-Comparison-Between-2-Products-Instagram-Post-min-768x960(1).jpg',
#  'dataSet\\coldSore\\Grey-Minimalist-Difference-And-Comparison-Between-2-Products-Instagram-Post-min-768x960.jpg',
#  'dataSet\\coldSore\\Home-Remedies-Cold-Sores(1).jpg',
#  'dataSet\\coldSore\\Home-Remedies-Cold-Sores.jpg',
#  'dataSet\\coldSore\\home-remedies-for-cold-sores(1).jpeg',
#  'dataSet\\coldSore\\Home-Remedies-For-Cold-Sores(1).jpg',
#  'dataSet\\coldSore\\home-remedies-for-cold-sores-cold-sore-free-forever-help(1).jpg',
#  'dataSet\\coldSore\\home-remedies-for-cold-sores-cold-sore-free-forever-help.jpg',
#  'dataSet\\coldSore\\home-remedies-for-cold-sores.jpeg',
#  'dataSet\\coldSore\\Home-Remedies-For-Cold-Sores.jpg',
#  'dataSet\\coldSore\\How-to-Get-Rid-of-a-Cold-Sore(1).jpg',
#  'dataSet\\coldSore\\how-to-get-rid-of-a-cold-sore-1-600x1564(1).jpg',
#  'dataSet\\coldSore\\how-to-get-rid-of-a-cold-sore-1-600x1564.jpg',
#  'dataSet\\coldSore\\How-to-Get-Rid-of-a-Cold-Sore.jpg',
#  'dataSet\\coldSore\\How-to-Get-Rid-of-Cold-Sores-Fast(1).jpg',
#  'dataSet\\coldSore\\how-to-get-rid-of-cold-sores-fast-1-e1469699607615(1).jpg',
#  'dataSet\\coldSore\\how-to-get-rid-of-cold-sores-fast-1-e1469699607615.jpg',
#  'dataSet\\coldSore\\How-to-Get-Rid-of-Cold-Sores-Fast.jpg',
#  'dataSet\\coldSore\\how-to-get-rid-of-cold-sores-fb.jpg',
#  'dataSet\\coldSore\\How-to-Get-Rid-of-Cold-Sores-Overnight.jpg',
#  'dataSet\\coldSore\\How-to-get-rid-of-cold-sores.jpg',
#  'dataSet\\coldSore\\How-to-Treat-and-Prevent-Cold-Sores-LowRes-2-1.jpg',
#  'dataSet\\coldSore\\howtogetridofacoldsore1.jpg',
#  'dataSet\\coldSore\\image-3.jpg',
#  'dataSet\\coldSore\\image.jpeg',
#  'dataSet\\coldSore\\image12.jpeg',
#  'dataSet\\coldSore\\image14.jpg',
#  'dataSet\\coldSore\\image2.jpeg',
#  'dataSet\\coldSore\\image3.jpeg',
#  'dataSet\\coldSore\\image4.jpeg',
#  'dataSet\\coldSore\\image5.jpeg',
#  'dataSet\\coldSore\\image6.jpeg',
#  'dataSet\\coldSore\\image7.jpeg',
#  'dataSet\\coldSore\\image8.jpeg',
#  'dataSet\\coldSore\\image9.jpeg',
#  'dataSet\\coldSore\\iStock-689143454-resize.jpg',
#  'dataSet\\coldSore\\lip-ointment.jpg',
#  'dataSet\\coldSore\\M1700345-Herpes_Cold_Sore-SPL.width-320.jpg',
#  'dataSet\\coldSore\\M1700345-Herpes_Cold_Sore-SPL.width-767.jpg',
#  'dataSet\\coldSore\\M1700364-Cold_sores.jpg',
#  'dataSet\\coldSore\\M1700451-Cold_sores.jpg',
#  'dataSet\\coldSore\\maxresdefault.jpg',
#  'dataSet\\coldSore\\maxresdefault10.jpg',
#  'dataSet\\coldSore\\maxresdefault11.jpg',
#  'dataSet\\coldSore\\maxresdefault12.jpg',
#  'dataSet\\coldSore\\maxresdefault2.jpg',
#  'dataSet\\coldSore\\maxresdefault3.jpg',
#  'dataSet\\coldSore\\maxresdefault4.jpg',
#  'dataSet\\coldSore\\maxresdefault5.jpg',
#  'dataSet\\coldSore\\maxresdefault6.jpg',
#  'dataSet\\coldSore\\maxresdefault7.jpg',
#  'dataSet\\coldSore\\maxresdefault8.jpg',
#  'dataSet\\coldSore\\maxresdefault9.jpg',
#  'dataSet\\coldSore\\OIF.1P0c9aPPOYU2kpFQRTcMOw.jpg',
#  'dataSet\\coldSore\\OIF.5stvrAbVvMw7aYcxixRW7Q.jpg',
#  'dataSet\\coldSore\\OIF.Csl7ZixL7HqM6v14gMiNqQ.jpg',
#  'dataSet\\coldSore\\OIF.D7sS0aknTpqJeSc3I1BPKA.jpg',
#  'dataSet\\coldSore\\OIF.foCOpqD2JGPTeP4TKvXo2A.jpg',
#  'dataSet\\coldSore\\OIF.HpNLLZpNC9hI5pqvuMfAhQ.jpg',
#  'dataSet\\coldSore\\OIF.lw3GVDsii59ejRY2ZzLh2g.jpg',
#  'dataSet\\coldSore\\OIF.n5x1AnEcWneGSw60OxMTKQ.jpg',
#  'dataSet\\coldSore\\OIF.no0JuiEukapUPKC5UYlH3A.jpg',
#  'dataSet\\coldSore\\OIF.q8OpsfMelrzJ6JbJ11wD8w.jpg',
#  'dataSet\\coldSore\\OIF.TQHHJwJ1UkiABicOkodoEQ.jpg',
#  'dataSet\\coldSore\\OIF.XIl2oZDaqAZVVwlNMbJsSQ.jpg',
#  'dataSet\\coldSore\\OIF.yvmhbqK1tqwf3KoPXHr7Zg.jpg',
#  'dataSet\\coldSore\\OIF.ZnbC9FB7B9bsYApYizukLw.jpg',
#  'dataSet\\coldSore\\OIF.ZqS77g3RZ1PBAOWxhdA9EQ.jpg',
#  'dataSet\\coldSore\\OIP.-kRtFIOUgiImOXezSJZWSAHaTQ.jpg',
#  'dataSet\\coldSore\\OIP.-KwNDJvZdP7uZePzan8NqgHaEK.jpg',
#  'dataSet\\coldSore\\OIP.04yeMNcvaUTnsQc0bgzZmwAAAA.jpg',
#  'dataSet\\coldSore\\OIP.1Lqb6VLo6bsAJpiMN0FBGAHaDt.jpg',
#  'dataSet\\coldSore\\OIP.2jXDsVau1GtOtVbKIRsVTQAAAA.jpg',
#  'dataSet\\coldSore\\OIP.2qScFq9J3W14SzcJLKynGQHaE8.jpg',
#  'dataSet\\coldSore\\OIP.3x2L2s89t-2srkqO4cPW8AHaE8.jpg',
#  'dataSet\\coldSore\\OIP.453J4-ObYEkTGUgGAXxw9wHaEo.jpg',
#  'dataSet\\coldSore\\OIP.4nl1L7QCFaymw_Q6GYR_6QAAAA.jpg',
#  'dataSet\\coldSore\\OIP.50Eei7JyXwkkM7QuaHxfGAHaPj.jpg',
#  'dataSet\\coldSore\\OIP.5N3PEwoSlxXWkg0U9xlBLgHaF2.jpg',
#  'dataSet\\coldSore\\OIP.5TCJ2BaFLhrNeBIoZhdgxAHaFx.jpg',
#  'dataSet\\coldSore\\OIP.5tj0RMhvQvDT0gXwCjspPwHaE6.jpg',
#  'dataSet\\coldSore\\OIP.5xYwKQohWGHB3OXBx2oBewEsDL.jpg',
#  'dataSet\\coldSore\\OIP.65zxIj62aMeOWouUCkv9nAHaE8.jpg',
#  'dataSet\\coldSore\\OIP.6f1WARyVRYDpHeY0USLOHgHaHp.jpg',
#  'dataSet\\coldSore\\OIP.6HfIXs6pHIA_z-G_9tg2pwHaED.jpg',
#  'dataSet\\coldSore\\OIP.6VnSp5mFbCfANMWJdO6oSgHaE8.jpg',
#  'dataSet\\coldSore\\OIP.7G4miLJiLYRYKHZ0glzqswHaDt.jpg',
#  'dataSet\\coldSore\\OIP.7s9UfY9UiidEXje1nwEq1gHaE7.jpg',
#  'dataSet\\coldSore\\OIP.7wxKLROq87uNaqEIOQTd6gHaKB.jpg',
#  'dataSet\\coldSore\\OIP.8hx7zdTz0kkM8DCmI7vPlwHaFr.jpg',
#  'dataSet\\coldSore\\OIP.8JMabPr_I8DWkn6mlie18QHaSh.jpg',
#  'dataSet\\coldSore\\OIP.8u8HhCkDH_z2q5TPNN03zgHaDZ.jpg',
#  'dataSet\\coldSore\\OIP.9SXd0c0CHrWwQgFSa63YHAHaEK.jpg',
#  'dataSet\\coldSore\\OIP.adwRnh6756mTwupi3fBbeQHaEU.jpg',
#  'dataSet\\coldSore\\OIP.aEQQOAqZiHdfJEm637GXEwAAAA.jpg',
#  'dataSet\\coldSore\\OIP.aG5EG9w_QyXUJgVn_lwMYQHaGx.jpg',
#  'dataSet\\coldSore\\OIP.ah64gj-ydUZXmsHIaGd_IAHaE8.jpg',
#  'dataSet\\coldSore\\OIP.AqnZ48XPtfXU2WmIXSS4lAHaE8.jpg',
#  'dataSet\\coldSore\\OIP.avx_QwUzuUe7TRkFtjvYnwHaML.jpg',
#  'dataSet\\coldSore\\OIP.b0TLVyfSTI4B5UxQDeYMwgHaE6.jpg',
#  'dataSet\\coldSore\\OIP.bhlgoJNgzfjQ0jQVO13-vAHaE8.jpg',
#  'dataSet\\coldSore\\OIP.BlGbAnrluz-WdzCX2StGfAHaDx.jpg',
#  'dataSet\\coldSore\\OIP.bLMxWFabc2vFQfhpNlNhxwHaDW.jpg',
#  'dataSet\\coldSore\\OIP.bpv_5pzwLKOeizPgsCTQvwHaDW.jpg',
#  'dataSet\\coldSore\\OIP.Bt5p1aWnkdT5fExlSew8swHaF_.jpg',
#  'dataSet\\coldSore\\OIP.BWyksXeYCNgoPGV5J65rkQHaE7.jpg',
#  'dataSet\\coldSore\\OIP.c-anD9tGv0AjQH6a7lsYhAHaFu.jpg',
#  'dataSet\\coldSore\\OIP.c0B3Cgv9Eau_3kP2gEoQDgHaDx.jpg',
#  'dataSet\\coldSore\\OIP.c73Oxg9ZKBClRTBvvFz6WwHaE8.jpg',
#  'dataSet\\coldSore\\OIP.ceOoy8aAhgd9UhtvThHszwHaEK.jpg',
#  'dataSet\\coldSore\\OIP.CE_NrbeJ-s8hULtOfnDtkQHaEK.jpg',
#  'dataSet\\coldSore\\OIP.cgmrUedImWXrgfXM7rGPNwHaFC.jpg',
#  'dataSet\\coldSore\\OIP.cOERnU94td6KrPGbciNw7AHaK-.jpg',
#  'dataSet\\coldSore\\OIP.cPAZe9rkkFntzE5mAJSeFAHaGM.jpg',
#  'dataSet\\coldSore\\OIP.db4cRHiMGG79oU1dbtHo8gHaFw.jpg',
#  'dataSet\\coldSore\\OIP.DF4fVH4bnSOXoSY3xFSsQQHaD4.jpg',
#  'dataSet\\coldSore\\OIP.DJF7U_-GBTEHOt7XBrHAMAHaE6.jpg',
#  'dataSet\\coldSore\\OIP.DLNTlvvgqWO5yalYLH3Q4gHaE8.jpg',
#  'dataSet\\coldSore\\OIP.Dny5Ohb2AMU-wa6J9yv5FwHaDx.jpg',
#  'dataSet\\coldSore\\OIP.DqMw6QwfpJe9XxfmUrJL2QHaD6.jpg',
#  'dataSet\\coldSore\\OIP.DTXKr9p_6Q6xvUzXphy09AHaFC.jpg',
#  'dataSet\\coldSore\\OIP.Ducb5NNBYIqzhAfT6VuT5AAAAA.jpg',
#  'dataSet\\coldSore\\OIP.dwWE1gaaJSFK-LcBtOClSQHaEa.jpg',
#  'dataSet\\coldSore\\OIP.DYa9iNnO8J16y9Op0JvvFAHaGW.jpg',
#  'dataSet\\coldSore\\OIP.e84L7hwsH872rh_XnTdexgHaLH.jpg',
#  'dataSet\\coldSore\\OIP.ECDN_Ze5dyTZOSSE3J3DKQAAAA.jpg',
#  'dataSet\\coldSore\\OIP.EhGnbyQriZwgycGBUdzF3QHaE7.jpg',
#  'dataSet\\coldSore\\OIP.EkXh6Np8s9RJ9sCzwm9juAHaE8.jpg',
#  'dataSet\\coldSore\\OIP.eMQNzKoNdMHhhjxhHwm-rAHaKC.jpg',
#  'dataSet\\coldSore\\OIP.eMX5gCAWXQjwnnKrHB_niwHaE8.jpg',
#  'dataSet\\coldSore\\OIP.EuzhG68rtIj0FEnU-1AqygHaFT.jpg',
#  'dataSet\\coldSore\\OIP.EvpAo1oWSbyEb_zzq3eU4AHaE6.jpg',
#  'dataSet\\coldSore\\OIP.f7584e46R8Y_isGMGwOV1QHaEK.jpg',
#  'dataSet\\coldSore\\OIP.fBHBzAJwGZHsPnwPilLn3QHaE8.jpg',
#  'dataSet\\coldSore\\OIP.FEkgnE2HpdoX5_oXUzlRswHaE7.jpg',
#  'dataSet\\coldSore\\OIP.FR8LjbGstB_2RufQa9aTMQAAAA.jpg',
#  'dataSet\\coldSore\\OIP.G-aJRZS6Nw4dsdh-rm-7lgHaE7.jpg',
#  'dataSet\\coldSore\\OIP.gdD8iKUdokt6zuG2tmO0eAHaE9.jpg',
#  'dataSet\\coldSore\\OIP.gEgZrk6KRUBoNGIfAm093wHaD4.jpg',
#  'dataSet\\coldSore\\OIP.Gj5os1Xdux1pXRIe-BfjsgHaDt.jpg',
#  'dataSet\\coldSore\\OIP.GR3Etl7TU7kpYb_3LaxpSAHaDO.jpg',
#  'dataSet\\coldSore\\OIP.GrOdMb3jrm3Ell8D8jtGDgHaD8.jpg',
#  'dataSet\\coldSore\\OIP.GSiJQ91Vy5oc8ilGWve4mgHaEK.jpg',
#  'dataSet\\coldSore\\OIP.h0HYbu5_Y2015JXyBK-IAgHaE8.jpg',
#  'dataSet\\coldSore\\OIP.h3F8uIUf28ogaGyTyG6t2AHaFC.jpg',
#  'dataSet\\coldSore\\OIP.H3IUnFFRU86qyd8Gq09V3wHaE_.jpg',
#  'dataSet\\coldSore\\OIP.hex5nzlB5drdoOCLCQjnYAHaEK.jpg',
#  'dataSet\\coldSore\\OIP.hYm-Pny3UIOXcO03G3GHrgHaE8.jpg',
#  'dataSet\\coldSore\\OIP.I3kp7_LLABya0G0HguLDPAHaE5.jpg',
#  'dataSet\\coldSore\\OIP.IgTCqDpir62BA9NQSReWNAHaEL.jpg',
#  'dataSet\\coldSore\\OIP.ijJbLZ3UsInkfHglyYwCUwHaFj.jpg',
#  'dataSet\\coldSore\\OIP.IkJwsUUowJs68gMIsA-DWgHaE6.jpg',
#  'dataSet\\coldSore\\OIP.Im6XAZNXtBilvdg7v65Q3AHaCr.jpg',
#  'dataSet\\coldSore\\OIP.iOBivVHpcKkM7lbswpdyCAAAAA.jpg',
#  'dataSet\\coldSore\\OIP.iREJWGL1_qmKpqIHAWyJUwHaIN.jpg',
#  'dataSet\\coldSore\\OIP.iVEDzjBGwDztQfrRJLRvggHaE8.jpg',
#  'dataSet\\coldSore\\OIP.IWpIp5z2qU0FMqyqBfIvVAHaHN.jpg',
#  'dataSet\\coldSore\\OIP.IwzUutK8IlUnJiptTPz0SQHaEL.jpg',
#  'dataSet\\coldSore\\OIP.IYfwKaB3Oy-Z7zas1w-ytQHaE8.jpg',
#  'dataSet\\coldSore\\OIP.i_BkP5xvGDH2kaydC2lFCwHaFj.jpg',
#  'dataSet\\coldSore\\OIP.J-oB00FQuqKTh-XpDZSlhgHaGE.jpg',
#  'dataSet\\coldSore\\OIP.j4FRMCZRJsI_XBbo4syMKQHaHa.jpg',
#  'dataSet\\coldSore\\OIP.J5ACypNy5VUJD9fLaNi97wHaFj.jpg',
#  'dataSet\\coldSore\\OIP.J8tJxaQ_rhrXD1agInU5LwHaLG.jpg',
#  'dataSet\\coldSore\\OIP.J8xEGWYLgtE_PHdjlrRCxQHaHk.jpg',
#  'dataSet\\coldSore\\OIP.jOoNBT-OCO5KXspNUJg7SQHaHa.jpg',
#  'dataSet\\coldSore\\OIP.JptnqLZJwSa3Cc-8Q9LNCwHaE9.jpg',
#  'dataSet\\coldSore\\OIP.jSvYb8ZH8STd0GazX3D5YAHaEK.jpg',
#  'dataSet\\coldSore\\OIP.JTTvCSf2lQw2TyuFv2lhlAAAAA.jpg',
#  'dataSet\\coldSore\\OIP.JU2ASlGzWcxYizG3FhDzQwHaJl.jpg',
#  'dataSet\\coldSore\\OIP.jZ5YCwWN1hdbZk5WO_sHlQHaEK.jpg',
#  'dataSet\\coldSore\\OIP.K10saYTOEXRQf75OHVsOugHaE8.jpg',
#  'dataSet\\coldSore\\OIP.k8b3RSqMs-1RhllbzY476wHaEK.jpg',
#  'dataSet\\coldSore\\OIP.K8LO2QdcaBLEJvN16h41hwHaC-.jpg',
#  'dataSet\\coldSore\\OIP.ki5m0586_F2TZYjgE-Kq0QHaE7.jpg',
#  'dataSet\\coldSore\\OIP.kRh0Q5W3ao_jM_b5FLKECAHaFj.jpg',
#  'dataSet\\coldSore\\OIP.KvtdQ53A-vm2aarw8khkwwHaJ4.jpg',
#  'dataSet\\coldSore\\OIP.lDlaae_wvDJHQK75aGaF8wHaLH.jpg',
#  'dataSet\\coldSore\\OIP.LELi9EvpNBinUKi27RH2CQHaE8.jpg',
#  'dataSet\\coldSore\\OIP.LLBSBsme4jZnYX0oDoi3GAHaE6.jpg',
#  'dataSet\\coldSore\\OIP.lLkXT2mAcTCUgBFauhHRIQHaE7.jpg',
#  'dataSet\\coldSore\\OIP.LLXv9o8hffcXoN3iekIxSQHaEs.jpg',
#  'dataSet\\coldSore\\OIP.LNogkKkiyYj7QLQEfiqTHQHaFf.jpg',
#  'dataSet\\coldSore\\OIP.m6Se893C8KrfQAIyap7DBgAAAA.jpg',
#  'dataSet\\coldSore\\OIP.m8egITn9tA_4MskQk_m6vwHaEo.jpg',
#  'dataSet\\coldSore\\OIP.Mc58F14SstNSgk03Mzzn-AHaD8.jpg',
#  'dataSet\\coldSore\\OIP.mehppbzvCBIbKSz5ord9gAHaLH.jpg',
#  'dataSet\\coldSore\\OIP.MFvWBfZ-vFM2YidFQywc0wHaHa.jpg',
#  'dataSet\\coldSore\\OIP.mHoKBkGtnJpWgSMNiE6lYAHaFL.jpg',
#  'dataSet\\coldSore\\OIP.mPge7AHVl7TzLb5vVSN3OQHaEK.jpg',
#  'dataSet\\coldSore\\OIP.MvWBuxbR_W8c1U8KVKW7QQHaFj.jpg',
#  'dataSet\\coldSore\\OIP.mwPTOD2fcGAAYqSHLvlCtgHaD1.jpg',
#  'dataSet\\coldSore\\OIP.NF3I83wVm9vpWLKN6uXtcAHaF0.jpg',
#  'dataSet\\coldSore\\OIP.njZhy3Fo74y5QQ6PuXh2BwHaE8.jpg',
#  'dataSet\\coldSore\\OIP.nNyAbwGCkW4GjxqP5OMVAwHaHa.jpg',
#  'dataSet\\coldSore\\OIP.nxDbl0iSosxFK0AaAB7H7QHaFj.jpg',
#  'dataSet\\coldSore\\OIP.O2VvHhN5V-bM2_qNkryLiAHaD4.jpg',
#  'dataSet\\coldSore\\OIP.O9Ujk5SCgcpFvMSOI1IKgQHaCr.jpg',
#  'dataSet\\coldSore\\OIP.ofTYVqCOcMOKHgK20tK70AHaEU.jpg',
#  'dataSet\\coldSore\\OIP.Oko5XAyEQZJ670K7VoTFagHaEK.jpg',
#  'dataSet\\coldSore\\OIP.oMlYC_ApirFZVOsexwo94gHaEK.jpg',
#  'dataSet\\coldSore\\OIP.OMNPTT-jkZ-eHL5bhfqwpAHaLW.jpg',
#  'dataSet\\coldSore\\OIP.omQutzRAmP5DWsVamgArogHaCP.jpg',
#  'dataSet\\coldSore\\OIP.oqcbkR3wuAlG_f-uHwrF8QAAAA.jpg',
#  'dataSet\\coldSore\\OIP.OSfJ6PXP_Yz3YDNP4QDLiwHaPj.jpg',
#  'dataSet\\coldSore\\OIP.OsPjMQvfWVC88dGR9st1ZAHaHa.jpg',
#  'dataSet\\coldSore\\OIP.Otcrx0akYQr4sZ_lA48tDwHaE8.jpg',
#  'dataSet\\coldSore\\OIP.P-G_meCVHcgnyG-bXfMv0AHaE8.jpg',
#  'dataSet\\coldSore\\OIP.PbQzcv9bM2EjCMtpmpN9CQHaE6.jpg',
#  'dataSet\\coldSore\\OIP.PGKq42PfMVwa7gvzOW9VkAHaEZ.jpg',
#  'dataSet\\coldSore\\OIP.PLciKNTlfgow--DEWhVY8AHaEK.jpg',
#  'dataSet\\coldSore\\OIP.QKs5KjVyTKgRqDNpSMHVcAHaE8.jpg',
#  'dataSet\\coldSore\\OIP.QO5CmPaDNu_UuoiuzNOwigHaEK.jpg',
#  'dataSet\\coldSore\\OIP.qP0YQlbI6Bx_N7aQJuX_MQHaDu.jpg',
#  'dataSet\\coldSore\\OIP.QPnTZPphT9bR4PPo2a32QAHaLH.jpg',
#  'dataSet\\coldSore\\OIP.qR_GlnROBMyKnSzNSLzdjQHaEK.jpg',
#  'dataSet\\coldSore\\OIP.qtOYRXOtr2IHUQcYZlTEVQHaE4.jpg',
#  'dataSet\\coldSore\\OIP.r2GikH-o8CXEdHbXpVgrQAHaD4.jpg',
#  'dataSet\\coldSore\\OIP.r3mK68VcC4vTUu0yo0g7lQHaDP.jpg',
#  'dataSet\\coldSore\\OIP.r7M7c4rhP5p36BYVYN5RAwHaEa.jpg',
#  'dataSet\\coldSore\\OIP.r9_gegZKBh2eXZCHr5kdGwHaE7.jpg',
#  'dataSet\\coldSore\\OIP.rP62i6Zta6sLonDUdtxLOAHaGG.jpg',
#  'dataSet\\coldSore\\OIP.RPef6NwG2LGuTC2kgbObcAHaCD.jpg',
#  'dataSet\\coldSore\\OIP.SaV5QXLOocgXEwnTozFzXgHaCu.jpg',
#  'dataSet\\coldSore\\OIP.SbGm9gRVrh8hV8NnKLFcegHaFj.jpg',
#  'dataSet\\coldSore\\OIP.SPzfG1gFqW7SMTwvK1XeSwHaIN.jpg',
#  'dataSet\\coldSore\\OIP.sUjHWr-HZjR5ka2VNMV4PQHaEK.jpg',
#  'dataSet\\coldSore\\OIP.svHRx_NUCAi3g1_iBfTe5gHaFj.jpg',
#  'dataSet\\coldSore\\OIP.SVUA0VqPYuJOYCy8l0zjJwHaJQ.jpg',
#  'dataSet\\coldSore\\OIP.S_7Bjv0-J7gEw1wsyS9GhQHaE8.jpg',
#  'dataSet\\coldSore\\OIP.TFHIou2T46HQyoWjRO2MDwHaD6.jpg',
#  'dataSet\\coldSore\\OIP.tHFJ9Mw0ffiCpwxBSI9rDQHaEK.jpg',
#  'dataSet\\coldSore\\OIP.TIG3VljNCKNR7Bp86T4boQHaGj.jpg',
#  'dataSet\\coldSore\\OIP.TP9w9IK6GX99A9dM2SbANgHaFC.jpg',
#  'dataSet\\coldSore\\OIP.TW7YsROMO4V68rYSUWkaQgHaD0.jpg',
#  'dataSet\\coldSore\\OIP.u8K5UM9LY9d4Kj3HowEU1wHaEu.jpg',
#  'dataSet\\coldSore\\OIP.Uc4jsdvkPfRpX99Of73fIQHaD3.jpg',
#  'dataSet\\coldSore\\OIP.UEe5ds9GqMVKYp6F74zhfAHaFj.jpg',
#  'dataSet\\coldSore\\OIP.uGJBTf-wXd4LdE51zdoMOQHaE6.jpg',
#  'dataSet\\coldSore\\OIP.uvJQmrrjPsHfSkNN8qC_FgHaFj.jpg',
#  'dataSet\\coldSore\\OIP.UyPC6VOQdBzK7sUyzwABhQHaE8.jpg',
#  'dataSet\\coldSore\\OIP.UZP07r--UG5jf_uU9CYafQHaE8.jpg',
#  'dataSet\\coldSore\\OIP.V1yF43Or4i1oIPPweWgr4QHaEK.jpg',
#  'dataSet\\coldSore\\OIP.V2gO0a1dKlIyA6JVLV3-9wHaE8.jpg',
#  'dataSet\\coldSore\\OIP.Va1MiM5HG8TMgnFPiG-f6gHaEE.jpg',
#  'dataSet\\coldSore\\OIP.VCz4xOUwDzhMJ8yTB1KEowHaE5.jpg',
#  'dataSet\\coldSore\\OIP.VdFbM1khDROv3SAxVC4KAgHaHa.jpg',
#  'dataSet\\coldSore\\OIP.vGKEuUUlNtdQRSSZj8edNgHaEK.jpg',
#  'dataSet\\coldSore\\OIP.VmWLNC-nw8S3ekaDpZzoOwHaEu.jpg',
#  'dataSet\\coldSore\\OIP.Vm_qy4V-nN6qfmyStqVlFgAAAA.jpg',
#  'dataSet\\coldSore\\OIP.VnKH-06Lm9WwzPlV0QLBJAHaE8.jpg',
#  'dataSet\\coldSore\\OIP.VolWcFw9cOG2eBcAYaS92gHaE6.jpg',
#  'dataSet\\coldSore\\OIP.VoZTvbUpS-P_JO6lBmcSUwHaE7.jpg',
#  'dataSet\\coldSore\\OIP.vUPTf-y1cOPXWp2HxahZWwHaE8.jpg',
#  'dataSet\\coldSore\\OIP.VYcT71iSftxvzlAX0L247gHaI3.jpg',
#  'dataSet\\coldSore\\OIP.vyVWAX4H9pRC30y_QbuLUgHaEK.jpg',
#  'dataSet\\coldSore\\OIP.W9gwQ7vsK_PTYcFKJMldDwHaTT.jpg',
#  'dataSet\\coldSore\\OIP.WolRWxQDc-JYmONzGvLzSgHaE8.jpg',
#  'dataSet\\coldSore\\OIP.wrm2nDDjPpfnVeesb2fQqQHaFj.jpg',
#  'dataSet\\coldSore\\OIP.wy7Bujszy64MfZZGXXzJSAHaD0.jpg',
#  'dataSet\\coldSore\\OIP.xB7QpELr_rduMKCv9JUllwHaE7.jpg',
#  'dataSet\\coldSore\\OIP.XblnYGcc5Chb1pinn-W3ogHaEK.jpg',
#  'dataSet\\coldSore\\OIP.xc2x6OopBqGQS77fYG_lWQHaDX.jpg',
#  'dataSet\\coldSore\\OIP.XEhRLC05FAnTWd5RueZ21AHaDm.jpg',
#  'dataSet\\coldSore\\OIP.XJzEXzTY3_BYvM_2k5AZ0AHaEJ.jpg',
#  'dataSet\\coldSore\\OIP.xLjhlFWv2mF6VHn6n6dvHQAAAA.jpg',
#  'dataSet\\coldSore\\OIP.xLjhlFWv2mF6VHn6n6dvHQAAAA2.jpg',
#  'dataSet\\coldSore\\OIP.xOCC-dvjL14gBXzmWWPulAHaLG.jpg',
#  'dataSet\\coldSore\\OIP.XRuL3y4jcZ3hncAVcgFyuQHaE9.jpg',
#  'dataSet\\coldSore\\OIP.y0GRloKSW5G0HPHuVzSoeQHaFj.jpg',
#  'dataSet\\coldSore\\OIP.Y0kUIfLrFSgACfaKV9OygAHaE7.jpg',
#  'dataSet\\coldSore\\OIP.yfcv31psP8bG0bnidWjRTgHaFr.jpg',
#  'dataSet\\coldSore\\OIP.YfCZGx3ZrPz-xNgQwHUSSgHaE7.jpg',
#  'dataSet\\coldSore\\OIP.YkQapU7O2bhO4yYAg3X7BgHaD4.jpg',
#  'dataSet\\coldSore\\OIP.YoR24rMPt4LupkHvmMqsVAAAAA.jpg',
#  'dataSet\\coldSore\\OIP.Yun0-kKremSnfEw_BYsMogAAAA.jpg',
#  'dataSet\\coldSore\\OIP.Z-oXtWq6Ym0tz2WpxDP9IAHaE7.jpg',
#  'dataSet\\coldSore\\OIP.ZHV6qfBIwoa0AfQh7BBSqgAAAA.jpg',
#  'dataSet\\coldSore\\OIP.ZwxT3ADS8zcj9QIEYFIeCQHaD0.jpg',
#  'dataSet\\coldSore\\OIP._Iuu9HvqsfaZ6zzLcptPTAHaLH.jpg',
#  'dataSet\\coldSore\\OIP._Q2j18SmNAKn_OfQjLP4iwHaHS.jpg',
#  'dataSet\\coldSore\\OIP._tAZE_oYE8nhKi9cktv6JQHaEL.jpg',
#  'dataSet\\coldSore\\OIP._uXySy_8DWakMlV7CY3YHQAAAA.jpg',
#  'dataSet\\coldSore\\Oral-herpes-1296x728-slide1.jpg',
#  'dataSet\\coldSore\\Riverside-Can-Help-Get-Rid-Of-Cold-Sores.jpg',
#  'dataSet\\coldSore\\Screen-Shot-2014-08-18-at-9.33.29-PM.png',
#  'dataSet\\coldSore\\sore-stage1.jpg',
#  'dataSet\\coldSore\\th.jpg',
#  'dataSet\\coldSore\\th10.jpg',
#  'dataSet\\coldSore\\th13.jpg',
#  'dataSet\\coldSore\\th19.jpg',
#  'dataSet\\coldSore\\th28.jpg',
#  'dataSet\\coldSore\\th36.jpg',
#  'dataSet\\coldSore\\th49.jpg',
#  'dataSet\\coldSore\\th50.jpg',
#  'dataSet\\coldSore\\th53.jpg',
#  'dataSet\\coldSore\\th54.jpg',
#  'dataSet\\coldSore\\th55.jpg',
#  'dataSet\\coldSore\\th56.jpg',
#  'dataSet\\coldSore\\th58.jpg',
#  'dataSet\\coldSore\\th59.jpg',
#  'dataSet\\coldSore\\th63.jpg',
#  'dataSet\\coldSore\\th64.jpg',
#  'dataSet\\coldSore\\th65.jpg',
#  'dataSet\\coldSore\\th66.jpg',
#  'dataSet\\coldSore\\th67.jpg',
#  'dataSet\\coldSore\\th68.jpg',
#  'dataSet\\coldSore\\th69.jpg',
#  'dataSet\\coldSore\\th72.jpg',
#  'dataSet\\coldSore\\th74.jpg',
#  'dataSet\\coldSore\\th75.jpg',
#  'dataSet\\coldSore\\th76.jpg',
#  'dataSet\\coldSore\\th77.jpg',
#  'dataSet\\coldSore\\th79.jpg',
#  'dataSet\\coldSore\\th80.jpg',
#  'dataSet\\coldSore\\th82.jpg',
#  'dataSet\\coldSore\\th83.jpg',
#  'dataSet\\coldSore\\th85.jpg',
#  'dataSet\\coldSore\\th86.jpg',
#  'dataSet\\coldSore\\th87.jpg',
#  'dataSet\\coldSore\\th88.jpg',
#  'dataSet\\coldSore\\th89.jpg',
#  'dataSet\\coldSore\\th91.jpg',
#  'dataSet\\coldSore\\th92.jpg',
#  'dataSet\\coldSore\\th93.jpg',
#  'dataSet\\coldSore\\th94.jpg',
#  'dataSet\\coldSore\\th95.jpg',
#  'dataSet\\coldSore\\th96.jpg',
#  'dataSet\\coldSore\\th97.jpg',
#  'dataSet\\coldSore\\treatments-cold-sores.jpg',
#  'dataSet\\coldSore\\What-are-Cold-Sores-Know-the-Signs-1024x683.jpg',
#  'dataSet\\coldSore\\What-are-Cold-Sores-Know-the-Signs-scaled.jpg',
#  'dataSet\\coldSore\\What-Are-Cold-Sores_article_main.jpg',
#  'dataSet\\coldSore\\what-is-a-cold-sore.jpg',
#  'dataSet\\coldSore\\what_causes_cold_sores.jpg',
#  'dataSet\\coldSore\\woman-mirror-cold-sore.jpg',
#  'dataSet\\coldSore\\_man-with-cold-sore.jpg',
#  'dataSet\\RingWorm\\12591540-6948751-image-a-11_1555977888528.jpg',
#  'dataSet\\RingWorm\\13-7.jpg',
#  'dataSet\\RingWorm\\15355-Ringworm-lesion-on-human-caught-from-cat.jpg',
#  'dataSet\\RingWorm\\15440_lores.jpg',
#  'dataSet\\RingWorm\\1eb8a2be-7382-4ad6-b875-be0f23aa490c_h230.jpg',
#  'dataSet\\RingWorm\\2oeuojalwm971.jpg',
#  'dataSet\\RingWorm\\2_641d6a3132715.jpeg',
#  'dataSet\\RingWorm\\322822_1100.jpg',
#  'dataSet\\RingWorm\\323242_2200-800x1200.jpg',
#  'dataSet\\RingWorm\\3256218.jpg',
#  'dataSet\\RingWorm\\3256221.jpg',
#  'dataSet\\RingWorm\\3256222_f496.jpg',
#  'dataSet\\RingWorm\\3cebd0f272b46d9dfb7d07a97ad19a5b.jpg',
#  'dataSet\\RingWorm\\650x350_ringworm_slideshow.jpg',
#  'dataSet\\RingWorm\\67636.jpg',
#  'dataSet\\RingWorm\\7807148_f520.jpg',
#  'dataSet\\RingWorm\\8337744.jpg',
#  'dataSet\\RingWorm\\8337745_f520.jpg',
#  'dataSet\\RingWorm\\A-Z_ringworm-1_22012020.jpg',
#  'dataSet\\RingWorm\\A-Z_ringworm-3_22012020.jpg',
#  'dataSet\\RingWorm\\a5b2b313-c789-417e-821e-2583738b5229_ringworm-rash.jpg',
#  'dataSet\\RingWorm\\A_1017_ringworm_BHJDDF.2e16d0ba.fill-920x613.jpg',
#  'dataSet\\RingWorm\\A_1017_ringworm_BPG17K.width-610.jpg',
#  'dataSet\\RingWorm\\BC-Ringworm--also-known-as-tinea-_1716ece354d_original-ratio.jpg',
#  'dataSet\\RingWorm\\C0222115-Ringworm.jpg',
#  'dataSet\\RingWorm\\C0222118-Ringworm_on_Neck.jpg',
#  'dataSet\\RingWorm\\C0345330-Ringworm_rash.jpg',
#  'dataSet\\RingWorm\\C0345331-Ringworm_rash.jpg',
#  'dataSet\\RingWorm\\C0345332-Ringworm_rash.jpg',
#  'dataSet\\RingWorm\\C0345332-Ringworm_rash2.jpg',
#  'dataSet\\RingWorm\\C0348796-Ringworm_fungal_infection.jpg',
#  'dataSet\\RingWorm\\CT07BH_3YG697J.width-1125.png',
#  'dataSet\\RingWorm\\dermatomycosis-corporis-3.jpg',
#  'dataSet\\RingWorm\\dermatomycosis-corporis-4.jpg',
#  'dataSet\\RingWorm\\dermatomycosis-corporis-7.jpg',
#  'dataSet\\RingWorm\\Difference-Between-Ringworm-and-Psoriasis.jpg',
#  'dataSet\\RingWorm\\ds00489_im02353_mcdc7_ringwormthu_jpg.jpg',
#  'dataSet\\RingWorm\\DS00489_IM02353_mcdc7_ringwormthu_jpg.png',
#  'dataSet\\RingWorm\\eczema.jpg',
#  'dataSet\\RingWorm\\EMR-110118-Figure-11-Erythema-Multiforme.jpg',
#  'dataSet\\RingWorm\\EMR-110118-Figure-2-EAC.jpg',
#  'dataSet\\RingWorm\\EMR-110118-Figure-3-GettyImages-587540436.jpg',
#  'dataSet\\RingWorm\\EMR-110118-Figure-7-Porokeratosis-of-Mibelli.jpg',
#  'dataSet\\RingWorm\\EZqlBqlXYAIVB7K.jpg',
#  'dataSet\\RingWorm\\f2f3c939dbbe0d0bf58dcb6097a1d902.jpg',
#  'dataSet\\RingWorm\\heroimage0.058572001600280917.jpg',
#  'dataSet\\RingWorm\\heroimage0.525362001600282655.jpg',
#  'dataSet\\RingWorm\\hGQinzx.jpg',
#  'dataSet\\RingWorm\\How-to-Treat-Ringworm.jpg',
#  'dataSet\\RingWorm\\image.jpeg',
#  'dataSet\\RingWorm\\image10.jpeg',
#  'dataSet\\RingWorm\\image11.jpeg',
#  'dataSet\\RingWorm\\image12.jpeg',
#  'dataSet\\RingWorm\\image13.jpeg',
#  'dataSet\\RingWorm\\image14.jpeg',
#  'dataSet\\RingWorm\\image15.jpeg',
#  'dataSet\\RingWorm\\image16.jpeg',
#  'dataSet\\RingWorm\\image17.jpeg',
#  'dataSet\\RingWorm\\image19.jpeg',
#  'dataSet\\RingWorm\\image2.jpeg',
#  'dataSet\\RingWorm\\image21.jpeg',
#  'dataSet\\RingWorm\\image22.jpeg',
#  'dataSet\\RingWorm\\image3.jpeg',
#  'dataSet\\RingWorm\\image4.jpeg',
#  'dataSet\\RingWorm\\image5.jpeg',
#  'dataSet\\RingWorm\\image6.jpeg',
#  'dataSet\\RingWorm\\image7.jpeg',
#  'dataSet\\RingWorm\\image8.jpeg',
#  'dataSet\\RingWorm\\image9.jpeg',
#  'dataSet\\RingWorm\\imgp2719.jpg',
#  'dataSet\\RingWorm\\is-it-ringworm.jpeg',
#  'dataSet\\RingWorm\\is-my-rash-ringworm-lifemd-feature-image.jpg',
#  'dataSet\\RingWorm\\iStock-93486007_wide.jpg',
#  'dataSet\\RingWorm\\large-96246-large-44880-screenshot-2017-06-14-23-05-41.png',
#  'dataSet\\RingWorm\\Lyme_Disease_Rash_on_5_year_old.jpg',
#  'dataSet\\RingWorm\\M2700050-Ringworm_on_arm.jpg',
#  'dataSet\\RingWorm\\M2700152-Close-up_of_ringworm_infection_on_gi.width-1019.jpg',
#  'dataSet\\RingWorm\\M2700152-Close-up_of_ringworm_infection_on_gir.width-767.jpg',
#  'dataSet\\RingWorm\\M2700313-Ringworm_fungal_infection-SPL.origina.width-767.jpg',
#  'dataSet\\RingWorm\\OIP.-upkYKdM_Ib9aVpK9bWYrAHaE8.jpg',
#  'dataSet\\RingWorm\\OIP.-Yv5Bdq54iqJHN3-9XnmFQHaHa.jpg',
#  'dataSet\\RingWorm\\OIP.0JVndlWMlrLRAOyuJlPglQHaE3.jpg',
#  'dataSet\\RingWorm\\OIP.0mYif6fy6p8z9eRXcnd6nAHaD5.jpg',
#  'dataSet\\RingWorm\\OIP.0XsPtT37JKqBQRSBOIcYKAHaE8.jpg',
#  'dataSet\\RingWorm\\OIP.1gR4IuRZnRaArRJJtM1adgHaE8.jpg',
#  'dataSet\\RingWorm\\OIP.1jamsA2q7D9XfF8JqrF9-QAAAA.jpg',
#  'dataSet\\RingWorm\\OIP.1Zw_N9vPsy7PFXJ42mXL-QHaE0.jpg',
#  'dataSet\\RingWorm\\OIP.2mVGnU8L-cq45kIaymBRSQHaE8.jpg',
#  'dataSet\\RingWorm\\OIP.4ax9wHz2LLUNaSbD3SvxxQHaD5.jpg',
#  'dataSet\\RingWorm\\OIP.4d-RuYQFYYyAU0tRtA65sAHaFj.jpg',
#  'dataSet\\RingWorm\\OIP.5z6e-TxQ9UFjuBOtN49ODAHaE7.jpg',
#  'dataSet\\RingWorm\\OIP.656aW62uANYvp_V8Uv-umQHaHN.jpg',
#  'dataSet\\RingWorm\\OIP.7M03m8pjNFuas8l5AezCqwHaEs.jpg',
#  'dataSet\\RingWorm\\OIP.7Phl-xsWdPG4t8SMjw2SRgHaFI.jpg',
#  'dataSet\\RingWorm\\OIP.7rzLgKszU0kOogFrT3VN5QHaFj.jpg',
#  'dataSet\\RingWorm\\OIP.7uueuvLBngPGjbgOflKMXQHaKZ.jpg',
#  'dataSet\\RingWorm\\OIP.7wyD1CfXROdy4iDVR04R0QHaSh.jpg',
#  'dataSet\\RingWorm\\OIP.96W4ho5oS3jOCHy2BFQKKwHaFj.jpg',
#  'dataSet\\RingWorm\\OIP.9KO48k6v4So1fKkGwsz8VQHaNa.jpg',
#  'dataSet\\RingWorm\\OIP.A1ytk1bpzLYLLPBgZjRD-AHaE7.jpg',
#  'dataSet\\RingWorm\\OIP.Ae0ns8gRCLrFzLa36_62JAHaFd.jpg',
#  'dataSet\\RingWorm\\OIP.aon-m2IKokgbIuY3RHmgTAHaFj.jpg',
#  'dataSet\\RingWorm\\OIP.at3IqnjZuTl6035liRKfQwHaLP.jpg',
#  'dataSet\\RingWorm\\OIP.beG8AMBtwYlQLaif9WTXdgHaLH.jpg',
#  'dataSet\\RingWorm\\OIP.bH1_Q4JFO_UOTiEYrNU-lgHaGr.jpg',
#  'dataSet\\RingWorm\\OIP.BjenuVhgW6rKynbRC77orgHaEu.jpg',
#  'dataSet\\RingWorm\\OIP.C3XkFP__ogwcPKZEchdtKAHaE8.jpg',
#  'dataSet\\RingWorm\\OIP.C4By16UhZMI3GlL5HBmZ_QAAAA.jpg',
#  'dataSet\\RingWorm\\OIP.cEXJEdMJ0RozVktkXMMLNAHaE6.jpg',
#  'dataSet\\RingWorm\\OIP.cK2CxpHyg5eSKRFwfviNiAHaIk.jpg',
#  'dataSet\\RingWorm\\OIP.cnzdWvlxt2dHgorN0B-6WAHaE8.jpg',
#  'dataSet\\RingWorm\\OIP.cR5o6tQKZSmi55bLe6z9JwHaJ4.jpg',
#  'dataSet\\RingWorm\\OIP.cxr1jrSujmB1jW5Q4rOEowHaJ4.jpg',
#  'dataSet\\RingWorm\\OIP.Cyc6ZcHAlzoJrSNkacPuxQHaEA.jpg',
#  'dataSet\\RingWorm\\OIP.CyZmS3idrCRJJEo47PLrDwHaF7.jpg',
#  'dataSet\\RingWorm\\OIP.D3XWorNzlrZiY2gGb9u2GgHaLP.jpg',
#  'dataSet\\RingWorm\\OIP.e7ZtUEJ4AynAKuQzYKgChAHaKv.jpg',
#  'dataSet\\RingWorm\\OIP.eaAIu5t4XQf75tjVDFIlGQHaRT.jpg',
#  'dataSet\\RingWorm\\OIP.eFkqZOhuwpOVQM1kt8xbJAAAAA.jpg',
#  'dataSet\\RingWorm\\OIP.Ek3kN4I70K6cc00qDsZx2AHaEs.jpg',
#  'dataSet\\RingWorm\\OIP.euAd04sQcsSGdFdhNWOxYQHaE8.jpg',
#  'dataSet\\RingWorm\\OIP.ezqysuNDKJxTiRgtcBb4TgHaHa.jpg',
#  'dataSet\\RingWorm\\OIP.Fce7vUFj-k-gs-eoOaajRAHaE8.jpg',
#  'dataSet\\RingWorm\\OIP.FjUwczUP0DVMp_QNDMhplQHaIP.jpg',
#  'dataSet\\RingWorm\\OIP.fujpNXEtV1qxIzNsNfnSfAHaFj.jpg',
#  'dataSet\\RingWorm\\OIP.gaAzgNsrjgPUb1LTSVKlCwHaE7.jpg',
#  'dataSet\\RingWorm\\OIP.gImctaN73bMe8WnBZrfVKQHaFB.jpg',
#  'dataSet\\RingWorm\\OIP.gOZUMHRr7y5Arp26tS3EYAHaFj.jpg',
#  'dataSet\\RingWorm\\OIP.GSUVo6e8ULzVBBzrph7GJwHaE7.jpg',
#  'dataSet\\RingWorm\\OIP.GtP_4kyPkOdWfmmR7cEmoQAAAA.jpg',
#  'dataSet\\RingWorm\\OIP.h8lh7HxZwaYb5JZ4cGBXSwHaE7.jpg',
#  'dataSet\\RingWorm\\OIP.hCPbJcDIxu2cqhj2v_FoCQHaEZ.jpg',
#  'dataSet\\RingWorm\\OIP.HYk2j0agYj6gWWfDksywVwHaE9.jpg',
#  'dataSet\\RingWorm\\OIP.ie5RgsOxTjBp3oET_mysGwAAAA.jpg',
#  'dataSet\\RingWorm\\OIP.jaFw10_qAqjtMn1I6T-rlQHaEJ.jpg',
#  'dataSet\\RingWorm\\OIP.Jew5dRWYYtZkuqpU8uKnvAHaE7.jpg',
#  'dataSet\\RingWorm\\OIP.JLi4RBJ3gnoRJSx4b0nx-AHaEU.jpg',
#  'dataSet\\RingWorm\\OIP.jTRC0GDFs2NAKpN7cFuJJQHaFB.jpg',
#  'dataSet\\RingWorm\\OIP.KbmdbAWodec1pVa97vdQ4gHaIq.jpg',
#  'dataSet\\RingWorm\\OIP.kjJINzXJQNwiUdUw_iziIAHaE7.jpg',
#  'dataSet\\RingWorm\\OIP.kUD-63hL2DlwPWXFixiFzAHaFz.jpg',
#  'dataSet\\RingWorm\\OIP.kUgkkh5jMBuK-BF9x8Z1DAHaFj.jpg',
#  'dataSet\\RingWorm\\OIP.Kwry8qQgOkYrfEgEDdJU1QAAAA.jpg',
#  'dataSet\\RingWorm\\OIP.L-vBKiUPWN9NqtA_EvL4CQHaE6.jpg',
#  'dataSet\\RingWorm\\OIP.LEJXo6J1ziOjnjlVqXDjjwHaEs.jpg',
#  'dataSet\\RingWorm\\OIP.lIGGVQaKdKJJjtvGXpL21QHaFj.jpg',
#  'dataSet\\RingWorm\\OIP.MpukhjN_A-b7Ugp8DLWvOgHaFH.jpg',
#  'dataSet\\RingWorm\\OIP.mretyg2Zh_v3_GUfmuVTIwHaEs.jpg',
#  'dataSet\\RingWorm\\OIP.nALMh5b7MLJOM2Ypfm37FQHaIq.jpg',
#  'dataSet\\RingWorm\\OIP.nBiXUTovI8Ow2X6-JX7UTQHaHf.jpg',
#  'dataSet\\RingWorm\\OIP.NmReLBj5kITHrbXxDs3ALQHaEK.jpg',
#  'dataSet\\RingWorm\\OIP.nOAZOdAU-94nxeixjtcyVQHaEJ.jpg',
#  'dataSet\\RingWorm\\OIP.NonFTA6_6Dy8I9CoQeg4JAAAAA.jpg',
#  'dataSet\\RingWorm\\OIP.NQjIZyKbHejiz8_STlh_7wHaE8.jpg',
#  'dataSet\\RingWorm\\OIP.NsOsPjT8Kq6XQDse-ZzX9wHaLG.jpg',
#  'dataSet\\RingWorm\\OIP.nTn2sOvwmqGRcLZiPCew2QHaFj.jpg',
#  'dataSet\\RingWorm\\OIP.o8yfrs9x5oEOuCqcE8jccgHaGx.jpg',
#  'dataSet\\RingWorm\\OIP.oERD-B-rSfuES8Ddxl45sgHaIq.jpg',
#  'dataSet\\RingWorm\\OIP.OgrFkMZG96R5QVtq8Ykr7wHaE8.jpg',
#  'dataSet\\RingWorm\\OIP.oLIS50KRcsEOdl-Ve-Tn1AHaE6.jpg',
#  'dataSet\\RingWorm\\OIP.OMNF_0jMHJITlGfahOhwygHaHa.jpg',
#  'dataSet\\RingWorm\\OIP.OVND-Cb5f1G7akeaekt2LwHaE8.jpg',
#  'dataSet\\RingWorm\\OIP.OyscPkSX5qgP7q4_volUogHaEK.jpg',
#  'dataSet\\RingWorm\\OIP.PJB6XR9iVZG6AbYKMgs7CwHaEs.jpg',
#  'dataSet\\RingWorm\\OIP.q47FHaSJF8NzboHw-PsgygHaGF.jpg',
#  'dataSet\\RingWorm\\OIP.qGkgYA-v6iaI2ByqMRLYCgHaD_.jpg',
#  'dataSet\\RingWorm\\OIP.QilfBIaIXWfBSno_iMkC0gHaE8.jpg',
#  'dataSet\\RingWorm\\OIP.QK8lQlIgPai8zZmEfzNnPgHaFj.jpg',
#  'dataSet\\RingWorm\\OIP.Qp79HnqmbU9E_OqHTF5J4AHaEJ.jpg',
#  'dataSet\\RingWorm\\OIP.rMrRG1zH2e1ZKURPJx9EdgHaEK.jpg',
#  'dataSet\\RingWorm\\OIP.rNdGqdMyb-lUhG-HDoZbEQHaCL.jpg',
#  'dataSet\\RingWorm\\OIP.rw_xhCjvDPUTzvEIqLEjBQHaFj.jpg',
#  'dataSet\\RingWorm\\OIP.rX-D-0uqy9KzAgTDBxJNrgHaHY.jpg',
#  'dataSet\\RingWorm\\OIP.RYBrdiAxK6R86wDm4lUsFAHaE8.jpg',
#  'dataSet\\RingWorm\\OIP.s0Ub9gqZQU_annpPy5wxMAHaE7.jpg',
#  'dataSet\\RingWorm\\OIP.sF4gRBZMGGZZnS3EgH1EgwHaE6.jpg',
#  'dataSet\\RingWorm\\OIP.Sgxj5d1alIYg67O-i2_BqwHaLH.jpg',
#  'dataSet\\RingWorm\\OIP.SoR_-jv4Xsxr-_cV_GizhwHaFK.jpg',
#  'dataSet\\RingWorm\\OIP.T1Gn-gWGT35GVZvXmelqzAHaEA.jpg',
#  'dataSet\\RingWorm\\OIP.ty0_KCxH2yyvtkLDZRVMAgHaEK.jpg',
#  'dataSet\\RingWorm\\OIP.U046jX2rfcc-lgBAdX2_AwHaIP.jpg',
#  'dataSet\\RingWorm\\OIP.Uk3hfrO6knayvLt4UDIu7wHaKw.jpg',
#  'dataSet\\RingWorm\\OIP.UOLOLb65ZQFGQmeozUU29AHaFB.jpg',
#  'dataSet\\RingWorm\\OIP.VFE_FUchIPXZAWVm_dTT8QHaFA.jpg',
#  'dataSet\\RingWorm\\OIP.vhDf4SEBwuyS5n058PcVoAHaHZ.jpg',
#  'dataSet\\RingWorm\\OIP.VHFMSNQzySqZlRwdenl4fgHaEK.jpg',
#  'dataSet\\RingWorm\\OIP.vXkLUyOe0P4XlphxUPyCPgHaFy.jpg',
#  'dataSet\\RingWorm\\OIP.W1Uhj-PdelB1GyFIDP8PfgHaEu.jpg',
#  'dataSet\\RingWorm\\OIP.xbOkD1jHzQu0E9IWp0NbdgHaJ4.jpg',
#  'dataSet\\RingWorm\\OIP.xe6Dx6d3GfwWhSW_eLO2PgAAAA.jpg',
#  'dataSet\\RingWorm\\OIP.xG5tsJVevAhxiu4O-l1fDAHaE8.jpg',
#  'dataSet\\RingWorm\\OIP.Xj5NWg1K3um74EVR_GuSkAHaE6.jpg',
#  'dataSet\\RingWorm\\OIP.XWp2KZ8Y9sctXwHcyx83vgHaFj.jpg',
#  'dataSet\\RingWorm\\OIP.xxrkVGykUm4rp3s1YuiRSgHaIN.jpg',
#  'dataSet\\RingWorm\\OIP.xYbPQPIEghj5GA0koQ6zMwHaHa.jpg',
#  'dataSet\\RingWorm\\OIP.XzSqpXITIxaTc4fAH-10nAHaFj.jpg',
#  'dataSet\\RingWorm\\OIP.ylfelUAmrBWrRIdzmAmDAQHaKw.jpg',
#  'dataSet\\RingWorm\\OIP.YRwRlSBceBnXSEM-NSWXggHaFj.jpg',
#  'dataSet\\RingWorm\\OIP.ZgiD0wv5rcwl5dY0VsyPkAAAAA.jpg',
#  'dataSet\\RingWorm\\OIP.ZLkK1zCGV4ITSuTjRDVsnwHaE7.jpg',
#  'dataSet\\RingWorm\\OIP.zmWvGomsgaWuFnLdWIp4xgHaFC.jpg',
#  'dataSet\\RingWorm\\OIP.ZRIwBPhPREPdKEzrJYoOUwHaEu.jpg',
#  'dataSet\\RingWorm\\OIP._exrAMBuLiH1_vrsc5lfqAHaEK.jpg',
#  'dataSet\\RingWorm\\OIP._jZIzZ0JXROX3_XFbPY8JgHaIU.jpg',
#  'dataSet\\RingWorm\\OIP._loBpDUzR0zk_QvpPI-sDAHaG9.jpg',
#  'dataSet\\RingWorm\\OIP.__JOe9OXa3ZyGKUwFZIiDAHaFj.jpg',
#  'dataSet\\RingWorm\\princ_rm_photo_of_ringworm_rash.jpg',
#  'dataSet\\RingWorm\\pyls6ahz15531.jpg',
#  'dataSet\\RingWorm\\rashes-that-look-like-ringworm-1024x683.jpg',
#  'dataSet\\RingWorm\\Ring-Rash.jpg',
#  'dataSet\\RingWorm\\Ringworm-1-768x768.jpg',
#  'dataSet\\RingWorm\\Ringworm-1.jpg',
#  'dataSet\\RingWorm\\Ringworm-1296x728-gallery_slide1.jpg',
#  'dataSet\\RingWorm\\ringworm-2.jpg',
#  'dataSet\\RingWorm\\Ringworm-768x504.jpg',
#  'dataSet\\RingWorm\\Ringworm-on-chest.jpg',
#  'dataSet\\RingWorm\\ringworm-on-neck.jpg',
#  'dataSet\\RingWorm\\ringworm-on-the-skin.jpg',
#  'dataSet\\RingWorm\\Ringworm-Pic-1568x1746.jpg',
#  'dataSet\\RingWorm\\Ringworm-Pic-768x855.jpg',
#  ...]

# %%
labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))
labels
# Out:
# ['acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'acne',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'cellulitis',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'coldSore',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  'RingWorm',
#  ...]

# %%
filepath = pd.Series(filepaths, name='Filepath').astype(str)
labels = pd.Series(labels, name='Label')
data=pd.concat([filepath, labels], axis=1)
data = data.sample(frac=1).reset_index(drop=True)
data.head(5)
# Out:
#                                             Filepath     Label
# 0  dataSet\coldSore\OIP.r3mK68VcC4vTUu0yo0g7lQHaD...  coldSore
# 1                 dataSet\coldSore\cold-sore5(1).jpg  coldSore
# 2  dataSet\Warts\8101b5a92056aa1a98c9fb487400b307...     Warts
# 3        dataSet\acne\phenolsubcisionsculptra1-6.jpg      acne
# 4                  dataSet\RingWorm\ringworm_4x3.jpg  RingWorm

# %%
counts = data.Label.value_counts()
sns.barplot(x=counts.index, y=counts)
plt.xlabel('Type')
plt.xticks(rotation=90);

# %%
train, test = train_test_split(data, test_size=0.25, random_state=42)

# %%
fig, axes =plt.subplots(nrows=5, ncols=5, figsize=(10,8),subplot_kw={'xticks':[],'yticks':[]})
for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(data.Filepath[i]))
    ax.set_title(data.Label[i])
plt.tight_layout()
plt.show()

# %%
train_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

# %%
train_gen = train_datagen.flow_from_dataframe(
    dataframe=train,
    x_col='Filepath',
    y_col='Label',
    target_size=(100,100),
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=42
)
valid_gen = train_datagen.flow_from_dataframe(
    dataframe=test,
    x_col='Filepath',
    y_col='Label',
    target_size=(100,100),
    class_mode='categorical',
    batch_size=32,
    shuffle=False,
    seed=42
)
test_gen = test_datagen.flow_from_dataframe(
    dataframe=test,
    x_col='Filepath',
    y_col='Label',
    target_size=(100,100),
    class_mode='categorical',
    batch_size=32,
    shuffle=False,
    seed=42
)
# Out:
# Found 1038 validated image filenames belonging to 5 classes.
# Found 345 validated image filenames belonging to 5 classes.
# Found 345 validated image filenames belonging to 5 classes.
# C:\Users\khair\AppData\Roaming\Python\Python311\site-packages\keras\src\legacy\preprocessing\image.py:920: UserWarning: Found 1 invalid image filename(s) in x_col="Filepath". These filename(s) will be ignored.
#   warnings.warn(
# C:\Users\khair\AppData\Roaming\Python\Python311\site-packages\keras\src\legacy\preprocessing\image.py:920: UserWarning: Found 1 invalid image filename(s) in x_col="Filepath". These filename(s) will be ignored.
#   warnings.warn(

# %%
pretrained_model = ResNet50(
    input_shape=(100,100, 3),
    include_top=False,
    weights='imagenet',
    pooling='avg'
)

pretrained_model.trainable = False

# %%
inputs = pretrained_model.input

x = Dense(128, activation='relu')(pretrained_model.output)
x = Dense(128, activation='relu')(x)

outputs = Dense(5, activation='softmax')(x)

model = Model(inputs=inputs, outputs=outputs)

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
my_callbacks = [EarlyStopping(monitor='val_accuracy',
                              min_delta=0,
                              patience=5,
                              mode='auto')]

# %%
history = model.fit(
    train_gen,
    validation_data=valid_gen,
    epochs=100
)
# Out:
# Epoch 1/100
# C:\Users\khair\AppData\Roaming\Python\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#  5/33 ━━━━━━━━━━━━━━━━━━━━ 13s 478ms/step - accuracy: 0.3886 - loss: 1.6118
# C:\Users\khair\AppData\Roaming\Python\Python311\site-packages\PIL\TiffImagePlugin.py:870: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 2.
#   warnings.warn(str(msg))
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 32s 663ms/step - accuracy: 0.5839 - loss: 1.1486 - val_accuracy: 0.8029 - val_loss: 0.5581
# Epoch 2/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 20s 573ms/step - accuracy: 0.8958 - loss: 0.3264 - val_accuracy: 0.8435 - val_loss: 0.4423
# Epoch 3/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 22s 644ms/step - accuracy: 0.9616 - loss: 0.1412 - val_accuracy: 0.9014 - val_loss: 0.3200
# Epoch 4/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 22s 635ms/step - accuracy: 0.9865 - loss: 0.0613 - val_accuracy: 0.8928 - val_loss: 0.3659
# Epoch 5/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 23s 682ms/step - accuracy: 0.9906 - loss: 0.0432 - val_accuracy: 0.9159 - val_loss: 0.3070
# Epoch 6/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 24s 692ms/step - accuracy: 0.9994 - loss: 0.0128 - val_accuracy: 0.9130 - val_loss: 0.3381
# Epoch 7/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 22s 636ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.9159 - val_loss: 0.3421
# Epoch 8/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 26s 773ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.9130 - val_loss: 0.3567
# Epoch 9/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 25s 740ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.9159 - val_loss: 0.3647
# Epoch 10/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 22s 630ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.9217 - val_loss: 0.3681
# Epoch 11/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 21s 624ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9217 - val_loss: 0.3786
# Epoch 12/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 20s 583ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9188 - val_loss: 0.3868
# Epoch 13/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 20s 575ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9188 - val_loss: 0.3949
# Epoch 14/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 22s 632ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9217 - val_loss: 0.3909
# Epoch 15/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 21s 614ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9217 - val_loss: 0.3995
# Epoch 16/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 22s 620ms/step - accuracy: 1.0000 - loss: 8.5219e-04 - val_accuracy: 0.9217 - val_loss: 0.4037
# Epoch 17/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 21s 616ms/step - accuracy: 1.0000 - loss: 8.1358e-04 - val_accuracy: 0.9188 - val_loss: 0.4093
# Epoch 18/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 22s 649ms/step - accuracy: 1.0000 - loss: 7.2428e-04 - val_accuracy: 0.9188 - val_loss: 0.4136
# Epoch 19/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 24s 686ms/step - accuracy: 1.0000 - loss: 6.0929e-04 - val_accuracy: 0.9188 - val_loss: 0.4202
# Epoch 20/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 24s 716ms/step - accuracy: 1.0000 - loss: 5.0355e-04 - val_accuracy: 0.9188 - val_loss: 0.4218
# Epoch 21/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 25s 723ms/step - accuracy: 1.0000 - loss: 4.9971e-04 - val_accuracy: 0.9217 - val_loss: 0.4223
# Epoch 22/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 24s 713ms/step - accuracy: 1.0000 - loss: 4.6355e-04 - val_accuracy: 0.9188 - val_loss: 0.4311
# Epoch 23/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 25s 716ms/step - accuracy: 1.0000 - loss: 4.3265e-04 - val_accuracy: 0.9159 - val_loss: 0.4298
# Epoch 24/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 26s 757ms/step - accuracy: 1.0000 - loss: 3.9670e-04 - val_accuracy: 0.9188 - val_loss: 0.4331
# Epoch 25/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 24s 715ms/step - accuracy: 1.0000 - loss: 3.8578e-04 - val_accuracy: 0.9188 - val_loss: 0.4373
# Epoch 26/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 26s 768ms/step - accuracy: 1.0000 - loss: 3.2377e-04 - val_accuracy: 0.9188 - val_loss: 0.4442
# Epoch 27/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 27s 791ms/step - accuracy: 1.0000 - loss: 3.0320e-04 - val_accuracy: 0.9188 - val_loss: 0.4448
# Epoch 28/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 22s 630ms/step - accuracy: 1.0000 - loss: 2.7301e-04 - val_accuracy: 0.9217 - val_loss: 0.4466
# Epoch 29/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 22s 638ms/step - accuracy: 1.0000 - loss: 2.4728e-04 - val_accuracy: 0.9188 - val_loss: 0.4526
# Epoch 30/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 23s 657ms/step - accuracy: 1.0000 - loss: 2.1067e-04 - val_accuracy: 0.9188 - val_loss: 0.4533
# Epoch 31/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 22s 646ms/step - accuracy: 1.0000 - loss: 2.3282e-04 - val_accuracy: 0.9217 - val_loss: 0.4580
# Epoch 32/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 22s 629ms/step - accuracy: 1.0000 - loss: 1.9135e-04 - val_accuracy: 0.9188 - val_loss: 0.4568
# Epoch 33/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 20s 582ms/step - accuracy: 1.0000 - loss: 1.8302e-04 - val_accuracy: 0.9188 - val_loss: 0.4617
# Epoch 34/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 20s 597ms/step - accuracy: 1.0000 - loss: 1.5454e-04 - val_accuracy: 0.9217 - val_loss: 0.4635
# Epoch 35/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 22s 625ms/step - accuracy: 1.0000 - loss: 1.7582e-04 - val_accuracy: 0.9188 - val_loss: 0.4681
# Epoch 36/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 22s 630ms/step - accuracy: 1.0000 - loss: 1.3900e-04 - val_accuracy: 0.9188 - val_loss: 0.4664
# Epoch 37/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 21s 627ms/step - accuracy: 1.0000 - loss: 1.5809e-04 - val_accuracy: 0.9188 - val_loss: 0.4716
# Epoch 38/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 22s 629ms/step - accuracy: 1.0000 - loss: 1.3040e-04 - val_accuracy: 0.9188 - val_loss: 0.4728
# Epoch 39/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 21s 617ms/step - accuracy: 1.0000 - loss: 1.2714e-04 - val_accuracy: 0.9188 - val_loss: 0.4759
# Epoch 40/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 23s 681ms/step - accuracy: 1.0000 - loss: 1.1760e-04 - val_accuracy: 0.9217 - val_loss: 0.4799
# Epoch 41/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 30s 867ms/step - accuracy: 1.0000 - loss: 1.2026e-04 - val_accuracy: 0.9188 - val_loss: 0.4800
# Epoch 42/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 22s 642ms/step - accuracy: 1.0000 - loss: 1.1158e-04 - val_accuracy: 0.9217 - val_loss: 0.4819
# Epoch 43/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 22s 634ms/step - accuracy: 1.0000 - loss: 1.0282e-04 - val_accuracy: 0.9217 - val_loss: 0.4853
# Epoch 44/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 25s 750ms/step - accuracy: 1.0000 - loss: 8.6518e-05 - val_accuracy: 0.9217 - val_loss: 0.4865
# Epoch 45/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 28s 806ms/step - accuracy: 1.0000 - loss: 9.7812e-05 - val_accuracy: 0.9217 - val_loss: 0.4879
# Epoch 46/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 24s 714ms/step - accuracy: 1.0000 - loss: 8.7788e-05 - val_accuracy: 0.9217 - val_loss: 0.4917
# Epoch 47/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 26s 759ms/step - accuracy: 1.0000 - loss: 9.0935e-05 - val_accuracy: 0.9217 - val_loss: 0.4919
# Epoch 48/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 23s 678ms/step - accuracy: 1.0000 - loss: 7.9548e-05 - val_accuracy: 0.9217 - val_loss: 0.4934
# Epoch 49/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 22s 625ms/step - accuracy: 1.0000 - loss: 6.9666e-05 - val_accuracy: 0.9217 - val_loss: 0.4952
# Epoch 50/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 23s 667ms/step - accuracy: 1.0000 - loss: 7.0086e-05 - val_accuracy: 0.9217 - val_loss: 0.4981
# Epoch 51/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 23s 667ms/step - accuracy: 1.0000 - loss: 6.7139e-05 - val_accuracy: 0.9217 - val_loss: 0.5003
# Epoch 52/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 23s 682ms/step - accuracy: 1.0000 - loss: 6.5889e-05 - val_accuracy: 0.9217 - val_loss: 0.5025
# Epoch 53/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 25s 735ms/step - accuracy: 1.0000 - loss: 5.4930e-05 - val_accuracy: 0.9217 - val_loss: 0.5038
# Epoch 54/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 21s 621ms/step - accuracy: 1.0000 - loss: 5.5981e-05 - val_accuracy: 0.9217 - val_loss: 0.5060
# Epoch 55/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 22s 642ms/step - accuracy: 1.0000 - loss: 5.6584e-05 - val_accuracy: 0.9217 - val_loss: 0.5071
# Epoch 56/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 23s 678ms/step - accuracy: 1.0000 - loss: 5.8513e-05 - val_accuracy: 0.9217 - val_loss: 0.5094
# Epoch 57/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 23s 661ms/step - accuracy: 1.0000 - loss: 4.7906e-05 - val_accuracy: 0.9217 - val_loss: 0.5108
# Epoch 58/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 23s 664ms/step - accuracy: 1.0000 - loss: 5.3678e-05 - val_accuracy: 0.9217 - val_loss: 0.5132
# Epoch 59/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 22s 643ms/step - accuracy: 1.0000 - loss: 4.3128e-05 - val_accuracy: 0.9217 - val_loss: 0.5149
# Epoch 60/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 21s 615ms/step - accuracy: 1.0000 - loss: 4.4217e-05 - val_accuracy: 0.9217 - val_loss: 0.5196
# Epoch 61/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 23s 665ms/step - accuracy: 1.0000 - loss: 4.0864e-05 - val_accuracy: 0.9217 - val_loss: 0.5190
# Epoch 62/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 24s 692ms/step - accuracy: 1.0000 - loss: 3.9669e-05 - val_accuracy: 0.9217 - val_loss: 0.5201
# Epoch 63/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 23s 679ms/step - accuracy: 1.0000 - loss: 4.0750e-05 - val_accuracy: 0.9217 - val_loss: 0.5231
# Epoch 64/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 25s 722ms/step - accuracy: 1.0000 - loss: 3.8517e-05 - val_accuracy: 0.9217 - val_loss: 0.5241
# Epoch 65/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 22s 637ms/step - accuracy: 1.0000 - loss: 3.7484e-05 - val_accuracy: 0.9217 - val_loss: 0.5257
# Epoch 66/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 23s 676ms/step - accuracy: 1.0000 - loss: 3.5797e-05 - val_accuracy: 0.9217 - val_loss: 0.5272
# Epoch 67/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 23s 676ms/step - accuracy: 1.0000 - loss: 3.4209e-05 - val_accuracy: 0.9217 - val_loss: 0.5292
# Epoch 68/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 23s 688ms/step - accuracy: 1.0000 - loss: 3.2643e-05 - val_accuracy: 0.9217 - val_loss: 0.5315
# Epoch 69/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 29s 847ms/step - accuracy: 1.0000 - loss: 3.3702e-05 - val_accuracy: 0.9217 - val_loss: 0.5314
# Epoch 70/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 24s 692ms/step - accuracy: 1.0000 - loss: 2.8765e-05 - val_accuracy: 0.9217 - val_loss: 0.5332
# Epoch 71/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 25s 719ms/step - accuracy: 1.0000 - loss: 2.9394e-05 - val_accuracy: 0.9217 - val_loss: 0.5356
# Epoch 72/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 24s 696ms/step - accuracy: 1.0000 - loss: 2.7067e-05 - val_accuracy: 0.9217 - val_loss: 0.5360
# Epoch 73/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 25s 714ms/step - accuracy: 1.0000 - loss: 2.8293e-05 - val_accuracy: 0.9217 - val_loss: 0.5389
# Epoch 74/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 25s 743ms/step - accuracy: 1.0000 - loss: 2.7939e-05 - val_accuracy: 0.9217 - val_loss: 0.5401
# Epoch 75/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 23s 666ms/step - accuracy: 1.0000 - loss: 2.5495e-05 - val_accuracy: 0.9217 - val_loss: 0.5414
# Epoch 76/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 25s 740ms/step - accuracy: 1.0000 - loss: 2.4545e-05 - val_accuracy: 0.9217 - val_loss: 0.5429
# Epoch 77/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 25s 719ms/step - accuracy: 1.0000 - loss: 2.5737e-05 - val_accuracy: 0.9217 - val_loss: 0.5450
# Epoch 78/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 25s 739ms/step - accuracy: 1.0000 - loss: 2.3707e-05 - val_accuracy: 0.9217 - val_loss: 0.5472
# Epoch 79/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 25s 736ms/step - accuracy: 1.0000 - loss: 2.1893e-05 - val_accuracy: 0.9246 - val_loss: 0.5473
# Epoch 80/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 23s 667ms/step - accuracy: 1.0000 - loss: 2.1160e-05 - val_accuracy: 0.9217 - val_loss: 0.5490
# Epoch 81/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 25s 750ms/step - accuracy: 1.0000 - loss: 2.1274e-05 - val_accuracy: 0.9246 - val_loss: 0.5505
# Epoch 82/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 26s 751ms/step - accuracy: 1.0000 - loss: 1.9090e-05 - val_accuracy: 0.9217 - val_loss: 0.5526
# Epoch 83/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 26s 745ms/step - accuracy: 1.0000 - loss: 1.8673e-05 - val_accuracy: 0.9217 - val_loss: 0.5542
# Epoch 84/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 26s 745ms/step - accuracy: 1.0000 - loss: 1.8712e-05 - val_accuracy: 0.9217 - val_loss: 0.5550
# Epoch 85/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 24s 684ms/step - accuracy: 1.0000 - loss: 1.6997e-05 - val_accuracy: 0.9246 - val_loss: 0.5573
# Epoch 86/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 26s 751ms/step - accuracy: 1.0000 - loss: 1.7507e-05 - val_accuracy: 0.9217 - val_loss: 0.5583
# Epoch 87/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 25s 738ms/step - accuracy: 1.0000 - loss: 1.6854e-05 - val_accuracy: 0.9217 - val_loss: 0.5607
# Epoch 88/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 26s 764ms/step - accuracy: 1.0000 - loss: 1.6118e-05 - val_accuracy: 0.9246 - val_loss: 0.5607
# Epoch 89/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 24s 703ms/step - accuracy: 1.0000 - loss: 1.4829e-05 - val_accuracy: 0.9246 - val_loss: 0.5630
# Epoch 90/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 23s 666ms/step - accuracy: 1.0000 - loss: 1.5811e-05 - val_accuracy: 0.9246 - val_loss: 0.5646
# Epoch 91/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 26s 732ms/step - accuracy: 1.0000 - loss: 1.4401e-05 - val_accuracy: 0.9246 - val_loss: 0.5651
# Epoch 92/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 26s 758ms/step - accuracy: 1.0000 - loss: 1.5583e-05 - val_accuracy: 0.9246 - val_loss: 0.5663
# Epoch 93/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 24s 699ms/step - accuracy: 1.0000 - loss: 1.3580e-05 - val_accuracy: 0.9246 - val_loss: 0.5681
# Epoch 94/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 25s 723ms/step - accuracy: 1.0000 - loss: 1.3478e-05 - val_accuracy: 0.9246 - val_loss: 0.5694
# Epoch 95/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 25s 726ms/step - accuracy: 1.0000 - loss: 1.4063e-05 - val_accuracy: 0.9246 - val_loss: 0.5711
# Epoch 96/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 23s 672ms/step - accuracy: 1.0000 - loss: 1.2187e-05 - val_accuracy: 0.9246 - val_loss: 0.5713
# Epoch 97/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 23s 676ms/step - accuracy: 1.0000 - loss: 1.3196e-05 - val_accuracy: 0.9246 - val_loss: 0.5729
# Epoch 98/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 25s 722ms/step - accuracy: 1.0000 - loss: 1.2104e-05 - val_accuracy: 0.9246 - val_loss: 0.5737
# Epoch 99/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 30s 867ms/step - accuracy: 1.0000 - loss: 1.1918e-05 - val_accuracy: 0.9246 - val_loss: 0.5764
# Epoch 100/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 28s 828ms/step - accuracy: 1.0000 - loss: 1.1305e-05 - val_accuracy: 0.9246 - val_loss: 0.5769

# %%
model.save("mode_resnet50.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
pd.DataFrame(history.history)[['accuracy','val_accuracy']].plot()
plt.title("Accuracy")
plt.show()

pd.DataFrame(history.history)[['loss','val_loss']].plot()
plt.title("Loss")
plt.show()

# %%
results = model.evaluate(test_gen, verbose=0)

print("   Test Loss: {:.5f}".format(results[0]))
print("Test Accuracy: {:.2f}%".format(results[1] * 100))
# Out:
# C:\Users\khair\AppData\Roaming\Python\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#    Test Loss: 0.57691
# Test Accuracy: 92.46%

# %%
pred = model.predict(test_gen)
pred = np.argmax(pred,axis=1)

labels = (train_gen.class_indices)
labels = dict((v,k) for k,v in labels.items())
pred = [labels[k] for k in pred]
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 491ms/step

# %%
y_test = list(test.Label)
print(classification_report(y_test, pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[87], line 2
#       1 y_test = list(test.Label)
# ----> 2 print(classification_report(y_test, pred))
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:2604, in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    2469 @validate_params(
#    2470     {
#    2471         "y_true": ["array-like", "sparse matrix"],
#    (...)
#    2495     zero_division="warn",
#    2496 ):
#    2497     """Build a text report showing the main classification metrics.
#    2498
#    2499     Read more in the :ref:`User Guide <classification_report>`.
#    (...)
#    2601     <BLANKLINE>
#    2602     """
# -> 2604     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    2606     if labels is None:
#    2607         labels = unique_labels(y_true, y_pred)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:85, in _check_targets(y_true, y_pred)
#      58 def _check_targets(y_true, y_pred):
#      59     """Check that y_true and y_pred belong to the same classification task.
#      60
#      61     This converts multiclass or binary types to a common shape, and raises a
#    (...)
#      83     y_pred : array or indicator matrix
#      84     """
# ---> 85     check_consistent_length(y_true, y_pred)
#      86     type_true = type_of_target(y_true, input_name="y_true")
#      87     type_pred = type_of_target(y_pred, input_name="y_pred")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:457, in check_consistent_length(*arrays)
#     455 uniques = np.unique(lengths)
#     456 if len(uniques) > 1:
# --> 457     raise ValueError(
#     458         "Found input variables with inconsistent numbers of samples: %r"
#     459         % [int(l) for l in lengths]
#     460     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [346, 345]

# %%
fig, axes = plt.subplots(nrows=5, ncols=4, figsize=(12,8),
                         subplot_kw={'xticks':[], 'yticks':[]})
for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(test.Filepath.iloc[i]))
    ax.set_title(f"True: {test.Label.iloc[i]}\nPredicted: {pred[i]}")
plt.tight_layout()
plt.show()

# %%
import cv2
import numpy as np
from matplotlib.pyplot import imread
from matplotlib.pyplot import imshow
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.imagenet_utils import decode_predictions
from tensorflow.keras.applications.imagenet_utils import preprocess_input

img_path='RW.jpg'

img = cv2.imread(img_path)
img = cv2.resize(img, (100,100))

x = np.expand_dims(img, axis=0)
x = preprocess_input(x)
result=model.predict(x)
print((result*100).astype('int'))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# [[99  0  0  0  0]]

# %%
from tensorflow.keras.models import load_model
loaded_model_imageNet  = load_model("mode_resnet50.h5")
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
import matplotlib.pyplot as plt

# %%
import cv2
import numpy as np
from matplotlib.pyplot import imread
from matplotlib.pyplot import imshow
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.imagenet_utils import decode_predictions
from tensorflow.keras.applications.imagenet_utils import preprocess_input

img_path='RW.jpg'

img = cv2.imread(img_path)
img = cv2.resize(img, (100,100))

x = np.expand_dims(img, axis=0)
x = preprocess_input(x)
result=model.predict(x)
print((result*100).astype('int'))

plt.imshow(img)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# [[99  0  0  0  0]]

# %%
p=list((result*100).astype('int'))
pp=list(p[0])
print(pp)
# Out:
# [99, 0, 0, 0, 0]

# %%
index = pp.index(max(pp))

# %%
name_class=['RingWorm','warts','acne','cellulitis','coldSore']

# %%
name_class[index]
# Out:
# 'RingWorm'

# %%
plt.title(name_class[index])
plt.imshow(img)
